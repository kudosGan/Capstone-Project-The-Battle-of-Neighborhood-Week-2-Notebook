# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods(Week 2)

# %% [markdown]
# Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name= "introduction"></a>

# %% [markdown]
# In this Project, we are trying to show the maximum possibility for a startup companies to start their companies in the City of Markham by presenting the city's increase prosperities. In their developing and the economy and talents to choose. Then city of Markham as the home for Life and start up their Family most cities succeed only if business people, who risk their own capital, Time, effort and ready to gamble on their Futures. To Retain the talents within the Canada The Federal Government came up with new Program called Global Talent Stream, Which is ready to help fast growing Canadian tech Companies recruit and retain highly skilled talent from going around the world.
#
# I have chosen City of Markham where I leverage the foursquare location data to solve the imagined business opportunity for the Startup tech companies. Why choosing the City of Markham Background on City of Markham. City of Markham located within the Greater Toronto Area of South of Ontario and located approximately 30km northeast of Downtown Toronto. Markham changed its status from Town of Markham to City of Markham in July 1 2012. Nearly produces 22% of its Labors force and has over 1000 technology and life science companies. Most high-tech companies like IBM, Honda Canada, Hyundai, AMD, Johnson and Johnson, Avaya, Motorola, Oracle, Toshiba, Huawei, Honeywell, CDI, Toshiba, GE Energy, Informatics, Nexeya Lenovo and Genesys. This also means that the market is highly competitive.as it is highly developing city cost of doing business is also high. Thus, any new business ventures or expansion needs to be analyze carefully to reduce risk and get back its ROI. Markham is under construction and developing stage of its own Downtown with more Entertainment Districts, Restaurants and Communities Parks with high raised Condominium, and University.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# ## Based on the Business Problem
# The Most Factors that will influence the Decision are:
# * Number of existing Schools in the neighborhood
# * Community Centre for Children and seniors
# * Schools, Kinder garden to High Schools, College and University
# * Hotels Golf Course and Restaurant with all the space to engaging the business related activities

# %% [markdown]
# We decided to use regularly spaced grid of locations, centered on Markham Downtown center, to define our neighborhoods.
#
# Following data sources, we will needed to extract/generate the required information:
# * Centers of candidate areas will be generated algorithmically and approximate addresses of centers of those areas will be obtained using **Google Maps API reverse geocoding**
# * Number of restaurants and their type and location in every neighborhood will be obtained using **Foursquare API**

# %% [markdown]
# Let us create latitude & longitude coordinates for centroids of our candidate neighborhoods. We will create a grid of cells covering our area of interest, which is approx. 300000 Radius centered on Downtown City of Markham.

# %% [markdown]
# #  City of Markham Downtown Latitude and Longitude

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-0                   --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_1              --> 2019.6.16-py36_1     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1c-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         868 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.2.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
# define the city and get its latitude & longitude 
city = 'downtown markham'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print ('Downtown Markham latitude & longitude :')
print( latitude, longitude)
# Out:
# Downtown Markham latitude & longitude :
# 43.828193 -79.3259721525424

# %% [markdown]
# Foursquare
# Now that we have our location, let us use Foursquare API to get info on School, Community Center, Hotel, and Restaurant, and Golf Course. In Downtown Markham.
#
# Foursquare credentials are  defined in hidden cell bellow.

# %%
ClIENT_ID = 'UQREUQKVGIBHLFGEYOVZPNV0JPMTKRJEBHJHTHZGQUIL0CTU' # your Foursquare ID
ClIENT_SECRET = 'KXG4WQ0ZJSIFST0P4VOORPECWP54IZUH5LPRH5YTRNKVZ323' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: UQREUQKVGIBHLFGEYOVZPNV0JPMTKRJEBHJHTHZGQUIL0CTU
# Foursquare_Secret:KXG4WQ0ZJSIFST0P4VOORPECWP54IZUH5LPRH5YTRNKVZ323

# %%
search_query = 'schools'
radius = 300000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=UQREUQKVGIBHLFGEYOVZPNV0JPMTKRJEBHJHTHZGQUIL0CTU&client_secret=KXG4WQ0ZJSIFST0P4VOORPECWP54IZUH5LPRH5YTRNKVZ323&ll=43.828193,-79.3259721525424&v=20180604&query=schools&radius=300000&limit=30'

# %%
school_results = requests.get(url).json()
#results
school_results
# Out:
# {'meta': {'code': 200, 'requestId': '5d533fdbdb1d810033659251'},
#  'response': {'venues': [{'id': '57924a7c498eec1c698aa0cb',
#     'name': 'Town Centre Montessori Schools (Milliken Campus)',
#     'location': {'address': '3 Clayton Dr',
#      'crossStreet': 'Kennedy Rd',
#      'lat': 43.82830590384543,
#      'lng': -79.30877455738575,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82830590384543,
#        'lng': -79.30877455738575}],
#      'distance': 1381,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['3 Clayton Dr (Kennedy Rd)',
#       'Markham ON',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a45',
#       'name': 'Preschool',
#       'pluralName': 'Preschools',
#       'shortName': 'Preschool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '5792503e498e68733099b054',
#     'name': 'Town Centre Montessori Schools (Amarillo Campus)',
#     'location': {'address': '76 Amarillo Ave',
#      'crossStreet': 'Denison St',
#      'lat': 43.83524695535469,
#      'lng': -79.3078043092753,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.83524695535469,
#        'lng': -79.3078043092753}],
#      'distance': 1656,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['76 Amarillo Ave (Denison St)',
#       'Markham ON',
#       'Canada']},
#     'categories': [{'id': '4f4533804b9074f6e4fb0105',
#       'name': 'Elementary School',
#       'pluralName': 'Elementary Schools',
#       'shortName': 'Elementary School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '51dc070d498e9309cdcf6ef2',
#     'name': 'Town Centre Montessori Schools (Main Campus)',
#     'location': {'address': '155 Clayton Dr',
#      'lat': 43.83191095092138,
#      'lng': -79.30998378276315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.83191095092138,
#        'lng': -79.30998378276315}],
#      'distance': 1349,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['155 Clayton Dr', 'Markham ON', 'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a46',
#       'name': 'Private School',
#       'pluralName': 'Private Schools',
#       'shortName': 'Private School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4bc200a8abf495219ec0c193',
#     'name': 'Eitz Chaim Day Schools - Administrative/Patricia Branch',
#     'location': {'address': '475 Patricia Ave.',
#      'crossStreet': 'at Bathurst St.',
#      'lat': 43.783501519208514,
#      'lng': -79.44480059603718,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.783501519208514,
#        'lng': -79.44480059603718}],
#      'distance': 10764,
#      'postalCode': 'M2R 2N1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['475 Patricia Ave. (at Bathurst St.)',
#       'Toronto ON M2R 2N1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1a8941735',
#       'name': 'General College & University',
#       'pluralName': 'General Colleges & Universities',
#       'shortName': 'Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4bd193e7caff95217ed9d0f0',
#     'name': 'Eitz Chaim Day Schools - Spring Farm Branch',
#     'location': {'address': '80 York Hill Blvd.',
#      'crossStreet': 'at Gallcrest Cir.',
#      'lat': 43.80341565290621,
#      'lng': -79.44496543623694,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.80341565290621,
#        'lng': -79.44496543623694}],
#      'distance': 9948,
#      'postalCode': 'L4J 2P6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['80 York Hill Blvd. (at Gallcrest Cir.)',
#       'Toronto ON L4J 2P6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'shortName': 'Classroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4cebff3afe90a35d781a560e',
#     'name': 'Eitz Chaim Day Schools - Viewmount Branch',
#     'location': {'address': '1 Viewmount Ave.',
#      'crossStreet': 'at Bathurst St.',
#      'lat': 43.70994631393894,
#      'lng': -79.42838821940076,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.70994631393894,
#        'lng': -79.42838821940076}],
#      'distance': 15525,
#      'postalCode': 'M5B 1T2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Viewmount Ave. (at Bathurst St.)',
#       'Toronto ON M5B 1T2',
#       'Canada']},
#     'categories': [{'id': '4f4533804b9074f6e4fb0105',
#       'name': 'Elementary School',
#       'pluralName': 'Elementary Schools',
#       'shortName': 'Elementary School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '55f1e78a498e054ec795e6c8',
#     'name': 'Mindtech Montessori Schools',
#     'location': {'lat': 43.867483,
#      'lng': -79.363144,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.867483,
#        'lng': -79.363144}],
#      'distance': 5294,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Markham ON', 'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a45',
#       'name': 'Preschool',
#       'pluralName': 'Preschools',
#       'shortName': 'Preschool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '581ba698b613dc5c31bfdb7e',
#     'name': 'Central Montessori Schools (Maplehurst Campus)',
#     'location': {'address': '181 Maplehurst Ave',
#      'lat': 43.763935,
#      'lng': -79.40282,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.763935,
#        'lng': -79.40282}],
#      'distance': 9449,
#      'postalCode': 'M2N 3C1',
#      'cc': 'CA',
#      'state': 'Ontario',
#      'country': 'Canada',
#      'formattedAddress': ['181 Maplehurst Ave', 'ON M2N 3C1', 'Canada']},
#     'categories': [{'id': '4f4533804b9074f6e4fb0105',
#       'name': 'Elementary School',
#       'pluralName': 'Elementary Schools',
#       'shortName': 'Elementary School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '5070914de4b0c34b5012fdf2',
#     'name': 'Northern Karate Schools',
#     'location': {'address': '865 York Mills Road',
#      'lat': 43.75449019937456,
#      'lng': -79.35032620834642,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.75449019937456,
#        'lng': -79.35032620834642}],
#      'distance': 8434,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['865 York Mills Road', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4f4528bc4b90abdf24c9de85',
#       'name': 'Athletics & Sports',
#       'pluralName': 'Athletics & Sports',
#       'shortName': 'Athletics & Sports',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4dffb9c052b10e74779891f8',
#     'name': 'Spirit of Math Schools Newtonbrook Campus',
#     'location': {'lat': 43.78921,
#      'lng': -79.4179,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.78921,
#        'lng': -79.4179}],
#      'distance': 8565,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4f15de89e4b0d85e5693b2c1',
#     'name': 'Whitefield Christian Schools',
#     'location': {'address': '5808 Finch Ave E',
#      'lat': 43.816877644190825,
#      'lng': -79.22945590550857,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.816877644190825,
#        'lng': -79.22945590550857}],
#      'distance': 7853,
#      'postalCode': 'M1B 4Y6',
#      'cc': 'CA',
#      'city': 'Scarborough',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5808 Finch Ave E',
#       'Scarborough ON M1B 4Y6',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4d84c2a7d5fab60c7111e89b',
#     'name': 'Beaches ITF Taekwon-Do Schools',
#     'location': {'address': '2975 Victoria Park Ave',
#      'crossStreet': 'Ellesmere',
#      'lat': 43.7589717,
#      'lng': -79.31560503333333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.7589717,
#        'lng': -79.31560503333333}],
#      'distance': 7750,
#      'postalCode': 'M1R 1V5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2975 Victoria Park Ave (Ellesmere)',
#       'Toronto ON M1R 1V5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d101941735',
#       'name': 'Martial Arts Dojo',
#       'pluralName': 'Martial Arts Dojos',
#       'shortName': 'Martial Arts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '56f310b2498ea87d6c5e2a4d',
#     'name': 'Spirit of Math Schools Markham East',
#     'location': {'address': '9293 Markham Road',
#      'lat': 43.89455252788598,
#      'lng': -79.26337480545044,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.89455252788598,
#        'lng': -79.26337480545044}],
#      'distance': 8933,
#      'postalCode': 'L6E 1A3',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['9293 Markham Road',
#       'Markham ON L6E 1A3',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a46',
#       'name': 'Private School',
#       'pluralName': 'Private Schools',
#       'shortName': 'Private School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '172440684'},
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4d9c62977865a0934f0fcf7a',
#     'name': 'Mindtech Montessori Schools',
#     'location': {'lat': 43.938602420493424,
#      'lng': -79.27486457019296,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.938602420493424,
#        'lng': -79.27486457019296}],
#      'distance': 12956,
#      'cc': 'CA',
#      'city': 'Dickson Hill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Dickson Hill ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'shortName': 'High School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '599f4d9dd0a149403ac4da70',
#     'name': 'Amberson High School - South Campus',
#     'location': {'address': '3470 Pharmacy Avenue',
#      'crossStreet': 'Pharmacy and Gorden Baker',
#      'lat': 43.808889143556605,
#      'lng': -79.33364868164062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.808889143556605,
#        'lng': -79.33364868164062}],
#      'distance': 2235,
#      'postalCode': 'M1W 2S7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['3470 Pharmacy Avenue (Pharmacy and Gorden Baker)',
#       'Toronto ON M1W 2S7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'shortName': 'High School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4cc34865b2beb1f7ecae154c',
#     'name': 'Northern Karate Schools',
#     'location': {'lat': 43.727457003602986,
#      'lng': -79.34432519043322,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.727457003602986,
#        'lng': -79.34432519043322}],
#      'distance': 11310,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4b69b1fcf964a52028ae2be3',
#     'name': 'Associated Hebrew Schools - Kamin',
#     'location': {'address': '300 Atkinson',
#      'lat': 43.81421628893565,
#      'lng': -79.4440588114827,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.81421628893565,
#        'lng': -79.4440588114827}],
#      'distance': 9611,
#      'cc': 'CA',
#      'city': 'Vaughan',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['300 Atkinson', 'Vaughan ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4cb9c0d64c60a093d5aa41ca',
#     'name': 'Northern Karate Schools',
#     'location': {'address': '11160 Yonge St',
#      'crossStreet': 'at Brookside Rd',
#      'lat': 43.899362,
#      'lng': -79.443838,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.899362,
#        'lng': -79.443838}],
#      'distance': 12339,
#      'postalCode': 'L4S 1H5',
#      'cc': 'CA',
#      'city': 'Richmond Hill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['11160 Yonge St (at Brookside Rd)',
#       'Richmond Hill ON L4S 1H5',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '598be7e846e1b670967eb8df',
#     'name': 'Best Driving Schools in Scarborough',
#     'location': {'address': '3464 kingston Road',
#      'crossStreet': 'Unit 204',
#      'lat': 43.73688705040569,
#      'lng': -79.21881794929504,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73688705040569,
#        'lng': -79.21881794929504}],
#      'distance': 13321,
#      'postalCode': 'M1M 1R5',
#      'cc': 'CA',
#      'city': 'Scarborough',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['3464 kingston Road (Unit 204)',
#       'Scarborough ON M1M 1R5',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a42',
#       'name': 'Driving School',
#       'pluralName': 'Driving Schools',
#       'shortName': 'Driving School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '56f31769498e46c1f1570ac1',
#     'name': 'Spirit of Math Schools Vaughan',
#     'location': {'address': '9860 Keele Street',
#      'lat': 43.85090062082381,
#      'lng': -79.5118761062622,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.85090062082381,
#        'lng': -79.5118761062622}],
#      'distance': 15139,
#      'postalCode': 'L6A 3Y4',
#      'cc': 'CA',
#      'city': 'Vaughan',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['9860 Keele Street',
#       'Vaughan ON L6A 3Y4',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a46',
#       'name': 'Private School',
#       'pluralName': 'Private Schools',
#       'shortName': 'Private School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '172441863'},
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4af0ac4ef964a52027de21e3',
#     'name': 'Schools Without Borders',
#     'location': {'address': '358 Dufferin',
#      'lat': 43.64118464753421,
#      'lng': -79.42862833715908,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64118464753421,
#        'lng': -79.42862833715908}],
#      'distance': 22395,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['358 Dufferin', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4b58f156f964a5208c7428e3',
#     'name': 'Northern Karate Schools - Midtown',
#     'location': {'address': '756 St Clair Ave W',
#      'crossStreet': 'St. Clair and Christie',
#      'lat': 43.681208,
#      'lng': -79.428296,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.681208,
#        'lng': -79.428296}],
#      'distance': 18314,
#      'postalCode': 'M6C 1B5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['756 St Clair Ave W (St. Clair and Christie)',
#       'Toronto ON M6C 1B5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d101941735',
#       'name': 'Martial Arts Dojo',
#       'pluralName': 'Martial Arts Dojos',
#       'shortName': 'Martial Arts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '83258231'},
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '5114201ee4b08f53b170e5ce',
#     'name': 'Medix School Student Lounge',
#     'location': {'lat': 43.791148602025906,
#      'lng': -79.24604277339368,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.791148602025906,
#        'lng': -79.24604277339368}],
#      'distance': 7631,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '5006bafe582f655c6e2088d5',
#     'name': 'Spirit of Math Schools The Beach',
#     'location': {'address': '415 Broadview Ave',
#      'crossStreet': 'Broadview and Gerrard',
#      'lat': 43.66641257115568,
#      'lng': -79.35272455215454,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66641257115568,
#        'lng': -79.35272455215454}],
#      'distance': 18137,
#      'postalCode': 'M4K 2M9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['415 Broadview Ave (Broadview and Gerrard)',
#       'Toronto ON M4K 2M9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4b87001df964a520a8aa31e3',
#     'name': 'University of Toronto Schools',
#     'location': {'address': '371 Bloor St. W',
#      'crossStreet': 'Spadina Ave.',
#      'lat': 43.6670414984732,
#      'lng': -79.40177271281063,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6670414984732,
#        'lng': -79.40177271281063}],
#      'distance': 18946,
#      'postalCode': 'M5S 2R7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['371 Bloor St. W (Spadina Ave.)',
#       'Toronto ON M5S 2R7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'shortName': 'High School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '5c67d96fbf7dde002c889aca',
#     'name': "Felix's Swim Schools",
#     'location': {'address': '181 Broadview Avenue',
#      'lat': 43.66111937681294,
#      'lng': -79.35045540332794,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66111937681294,
#        'lng': -79.35045540332794}],
#      'distance': 18702,
#      'postalCode': 'M4M 2G3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['181 Broadview Avenue',
#       'Toronto ON M4M 2G3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4ff84bd8e4b0211bc31f4d28',
#     'name': 'Northern Karate Schools',
#     'location': {'address': '135-14800 Yonge St',
#      'lat': 43.988181,
#      'lng': -79.464814,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.988181,
#        'lng': -79.464814}],
#      'distance': 21004,
#      'postalCode': 'L4G 1N3',
#      'cc': 'CA',
#      'city': 'Aurora',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['135-14800 Yonge St',
#       'Aurora ON L4G 1N3',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '5475e2d3498ef6bf858a200a',
#     'name': 'Brockton TDSB Caring and Safe Schools',
#     'location': {'lat': 43.65779113769531,
#      'lng': -79.43862915039062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65779113769531,
#        'lng': -79.43862915039062}],
#      'distance': 21021,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '5c965f774a1cc0002cd62560',
#     'name': 'Blessed Sacrament School Soccer Field',
#     'location': {'address': '24 Bedford Park Ave',
#      'lat': 43.727192,
#      'lng': -79.404945,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.727192,
#        'lng': -79.404945}],
#      'distance': 12911,
#      'postalCode': 'M5M 1H9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['24 Bedford Park Ave',
#       'Toronto ON M5M 1H9',
#       'Canada']},
#     'categories': [{'id': '4cce455aebf7b749d5e191f5',
#       'name': 'Soccer Field',
#       'pluralName': 'Soccer Fields',
#       'shortName': 'Soccer Field',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_soccer_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False},
#    {'id': '4ebff0d661af06192b50b3bd',
#     'name': 'Ahvat Yisroel Hebrew School Stephen Lewis Campus',
#     'location': {'lat': 43.835959186628855,
#      'lng': -79.47636210141518,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.835959186628855,
#        'lng': -79.47636210141518}],
#      'distance': 12107,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736923',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
school_venues = school_results['response']['venues']

# tranform venues into a dataframe
school_venues = json_normalize(school_venues)
school_venues.head (10)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '52e81612bcbc57f1066b7a45', 'name': 'P...    False
# 1  [{'id': '4f4533804b9074f6e4fb0105', 'name': 'E...    False
# 2  [{'id': '52e81612bcbc57f1066b7a46', 'name': 'P...    False
# 3  [{'id': '4bf58dd8d48988d1a8941735', 'name': 'G...    False
# 4  [{'id': '4bf58dd8d48988d1a0941735', 'name': 'C...    False
# 5  [{'id': '4f4533804b9074f6e4fb0105', 'name': 'E...    False
# 6  [{'id': '52e81612bcbc57f1066b7a45', 'name': 'P...    False
# 7  [{'id': '4f4533804b9074f6e4fb0105', 'name': 'E...    False
# 8  [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...    False
# 9  [{'id': '4bf58dd8d48988d13b941735', 'name': 'S...    False
#
#                          id     location.address location.cc location.city  \
# 0  57924a7c498eec1c698aa0cb         3 Clayton Dr          CA       Markham
# 1  5792503e498e68733099b054      76 Amarillo Ave          CA       Markham
# 2  51dc070d498e9309cdcf6ef2       155 Clayton Dr          CA       Markham
# 3  4bc200a8abf495219ec0c193    475 Patricia Ave.          CA       Toronto
# 4  4bd193e7caff95217ed9d0f0   80 York Hill Blvd.          CA       Toronto
# 5  4cebff3afe90a35d781a560e     1 Viewmount Ave.          CA       Toronto
# 6  55f1e78a498e054ec795e6c8                  NaN          CA       Markham
# 7  581ba698b613dc5c31bfdb7e   181 Maplehurst Ave          CA           NaN
# 8  5070914de4b0c34b5012fdf2  865 York Mills Road          CA       Toronto
# 9  4dffb9c052b10e74779891f8                  NaN          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada           Kennedy Rd               1381
# 1           Canada           Denison St               1656
# 2           Canada                  NaN               1349
# 3           Canada      at Bathurst St.              10764
# 4           Canada    at Gallcrest Cir.               9948
# 5           Canada      at Bathurst St.              15525
# 6           Canada                  NaN               5294
# 7           Canada                  NaN               9449
# 8           Canada                  NaN               8434
# 9           Canada                  NaN               8565
#
#                            location.formattedAddress  \
# 0    [3 Clayton Dr (Kennedy Rd), Markham ON, Canada]
# 1  [76 Amarillo Ave (Denison St), Markham ON, Can...
# 2               [155 Clayton Dr, Markham ON, Canada]
# 3  [475 Patricia Ave. (at Bathurst St.), Toronto ...
# 4  [80 York Hill Blvd. (at Gallcrest Cir.), Toron...
# 5  [1 Viewmount Ave. (at Bathurst St.), Toronto O...
# 6                               [Markham ON, Canada]
# 7           [181 Maplehurst Ave, ON M2N 3C1, Canada]
# 8          [865 York Mills Road, Toronto ON, Canada]
# 9                               [Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.82830590384543...     43.828306
# 1  [{'label': 'display', 'lat': 43.83524695535469...     43.835247
# 2  [{'label': 'display', 'lat': 43.83191095092138...     43.831911
# 3  [{'label': 'display', 'lat': 43.78350151920851...     43.783502
# 4  [{'label': 'display', 'lat': 43.80341565290621...     43.803416
# 5  [{'label': 'display', 'lat': 43.70994631393894...     43.709946
# 6  [{'label': 'display', 'lat': 43.867483, 'lng':...     43.867483
# 7  [{'label': 'display', 'lat': 43.763935, 'lng':...     43.763935
# 8  [{'label': 'display', 'lat': 43.75449019937456...     43.754490
# 9  [{'label': 'display', 'lat': 43.78921, 'lng': ...     43.789210
#
#    location.lng location.postalCode location.state  \
# 0    -79.308775                 NaN             ON
# 1    -79.307804                 NaN             ON
# 2    -79.309984                 NaN             ON
# 3    -79.444801             M2R 2N1             ON
# 4    -79.444965             L4J 2P6             ON
# 5    -79.428388             M5B 1T2             ON
# 6    -79.363144                 NaN             ON
# 7    -79.402820             M2N 3C1        Ontario
# 8    -79.350326                 NaN             ON
# 9    -79.417900                 NaN             ON
#
#                                                 name    referralId  \
# 0   Town Centre Montessori Schools (Milliken Campus)  v-1565736923
# 1   Town Centre Montessori Schools (Amarillo Campus)  v-1565736923
# 2       Town Centre Montessori Schools (Main Campus)  v-1565736923
# 3  Eitz Chaim Day Schools - Administrative/Patric...  v-1565736923
# 4        Eitz Chaim Day Schools - Spring Farm Branch  v-1565736923
# 5          Eitz Chaim Day Schools - Viewmount Branch  v-1565736923
# 6                        Mindtech Montessori Schools  v-1565736923
# 7     Central Montessori Schools (Maplehurst Campus)  v-1565736923
# 8                            Northern Karate Schools  v-1565736923
# 9          Spirit of Math Schools Newtonbrook Campus  v-1565736923
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
school_venues_columns = ['name', 'categories'] + [col for col in school_venues.columns if col.startswith('location.')]+ ['id']
school_clean_dataframe = school_venues.loc[:,school_venues_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
school_clean_dataframe['categories'] = school_clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
school_clean_dataframe.columns = [column.split('.')[-1] for column in school_clean_dataframe.columns]

school_clean_dataframe.head(10)
# Out:
#                                                 name  \
# 0   Town Centre Montessori Schools (Milliken Campus)
# 1   Town Centre Montessori Schools (Amarillo Campus)
# 2       Town Centre Montessori Schools (Main Campus)
# 3  Eitz Chaim Day Schools - Administrative/Patric...
# 4        Eitz Chaim Day Schools - Spring Farm Branch
# 5          Eitz Chaim Day Schools - Viewmount Branch
# 6                        Mindtech Montessori Schools
# 7     Central Montessori Schools (Maplehurst Campus)
# 8                            Northern Karate Schools
# 9          Spirit of Math Schools Newtonbrook Campus
#
#                      categories              address  cc     city country  \
# 0                     Preschool         3 Clayton Dr  CA  Markham  Canada
# 1             Elementary School      76 Amarillo Ave  CA  Markham  Canada
# 2                Private School       155 Clayton Dr  CA  Markham  Canada
# 3  General College & University    475 Patricia Ave.  CA  Toronto  Canada
# 4             College Classroom   80 York Hill Blvd.  CA  Toronto  Canada
# 5             Elementary School     1 Viewmount Ave.  CA  Toronto  Canada
# 6                     Preschool                  NaN  CA  Markham  Canada
# 7             Elementary School   181 Maplehurst Ave  CA      NaN  Canada
# 8            Athletics & Sports  865 York Mills Road  CA  Toronto  Canada
# 9                        School                  NaN  CA  Toronto  Canada
#
#          crossStreet  distance  \
# 0         Kennedy Rd      1381
# 1         Denison St      1656
# 2                NaN      1349
# 3    at Bathurst St.     10764
# 4  at Gallcrest Cir.      9948
# 5    at Bathurst St.     15525
# 6                NaN      5294
# 7                NaN      9449
# 8                NaN      8434
# 9                NaN      8565
#
#                                     formattedAddress  \
# 0    [3 Clayton Dr (Kennedy Rd), Markham ON, Canada]
# 1  [76 Amarillo Ave (Denison St), Markham ON, Can...
# 2               [155 Clayton Dr, Markham ON, Canada]
# 3  [475 Patricia Ave. (at Bathurst St.), Toronto ...
# 4  [80 York Hill Blvd. (at Gallcrest Cir.), Toron...
# 5  [1 Viewmount Ave. (at Bathurst St.), Toronto O...
# 6                               [Markham ON, Canada]
# 7           [181 Maplehurst Ave, ON M2N 3C1, Canada]
# 8          [865 York Mills Road, Toronto ON, Canada]
# 9                               [Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.82830590384543...  43.828306 -79.308775
# 1  [{'label': 'display', 'lat': 43.83524695535469...  43.835247 -79.307804
# 2  [{'label': 'display', 'lat': 43.83191095092138...  43.831911 -79.309984
# 3  [{'label': 'display', 'lat': 43.78350151920851...  43.783502 -79.444801
# 4  [{'label': 'display', 'lat': 43.80341565290621...  43.803416 -79.444965
# 5  [{'label': 'display', 'lat': 43.70994631393894...  43.709946 -79.428388
# 6  [{'label': 'display', 'lat': 43.867483, 'lng':...  43.867483 -79.363144
# 7  [{'label': 'display', 'lat': 43.763935, 'lng':...  43.763935 -79.402820
# 8  [{'label': 'display', 'lat': 43.75449019937456...  43.754490 -79.350326
# 9  [{'label': 'display', 'lat': 43.78921, 'lng': ...  43.789210 -79.417900
#
#   postalCode    state                        id
# 0        NaN       ON  57924a7c498eec1c698aa0cb
# 1        NaN       ON  5792503e498e68733099b054
# 2        NaN       ON  51dc070d498e9309cdcf6ef2
# 3    M2R 2N1       ON  4bc200a8abf495219ec0c193
# 4    L4J 2P6       ON  4bd193e7caff95217ed9d0f0
# 5    M5B 1T2       ON  4cebff3afe90a35d781a560e
# 6        NaN       ON  55f1e78a498e054ec795e6c8
# 7    M2N 3C1  Ontario  581ba698b613dc5c31bfdb7e
# 8        NaN       ON  5070914de4b0c34b5012fdf2
# 9        NaN       ON  4dffb9c052b10e74779891f8

# %%
# delete unnecessary columns
school_clean_dataframe1=school_clean_dataframe.drop(['cc', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','id'], axis=1)
school_clean_dataframe1
# Out:
#                                                  name  \
# 0    Town Centre Montessori Schools (Milliken Campus)
# 1    Town Centre Montessori Schools (Amarillo Campus)
# 2        Town Centre Montessori Schools (Main Campus)
# 3   Eitz Chaim Day Schools - Administrative/Patric...
# 4         Eitz Chaim Day Schools - Spring Farm Branch
# 5           Eitz Chaim Day Schools - Viewmount Branch
# 6                         Mindtech Montessori Schools
# 7      Central Montessori Schools (Maplehurst Campus)
# 8                             Northern Karate Schools
# 9           Spirit of Math Schools Newtonbrook Campus
# 10                       Whitefield Christian Schools
# 11                     Beaches ITF Taekwon-Do Schools
# 12                Spirit of Math Schools Markham East
# 13                        Mindtech Montessori Schools
# 14                Amberson High School - South Campus
# 15                            Northern Karate Schools
# 16                  Associated Hebrew Schools - Kamin
# 17                            Northern Karate Schools
# 18                Best Driving Schools in Scarborough
# 19                     Spirit of Math Schools Vaughan
# 20                            Schools Without Borders
# 21                  Northern Karate Schools - Midtown
# 22                        Medix School Student Lounge
# 23                   Spirit of Math Schools The Beach
# 24                      University of Toronto Schools
# 25                               Felix's Swim Schools
# 26                            Northern Karate Schools
# 27              Brockton TDSB Caring and Safe Schools
# 28              Blessed Sacrament School Soccer Field
# 29   Ahvat Yisroel Hebrew School Stephen Lewis Campus
#
#                       categories                 address           city  \
# 0                      Preschool            3 Clayton Dr        Markham
# 1              Elementary School         76 Amarillo Ave        Markham
# 2                 Private School          155 Clayton Dr        Markham
# 3   General College & University       475 Patricia Ave.        Toronto
# 4              College Classroom      80 York Hill Blvd.        Toronto
# 5              Elementary School        1 Viewmount Ave.        Toronto
# 6                      Preschool                     NaN        Markham
# 7              Elementary School      181 Maplehurst Ave            NaN
# 8             Athletics & Sports     865 York Mills Road        Toronto
# 9                         School                     NaN        Toronto
# 10                          None        5808 Finch Ave E    Scarborough
# 11             Martial Arts Dojo  2975 Victoria Park Ave        Toronto
# 12                Private School       9293 Markham Road        Markham
# 13                   High School                     NaN   Dickson Hill
# 14                   High School    3470 Pharmacy Avenue        Toronto
# 15                          None                     NaN            NaN
# 16                        School            300 Atkinson        Vaughan
# 17                          None          11160 Yonge St  Richmond Hill
# 18                Driving School      3464 kingston Road    Scarborough
# 19                Private School       9860 Keele Street        Vaughan
# 20                      Building            358 Dufferin        Toronto
# 21             Martial Arts Dojo      756 St Clair Ave W        Toronto
# 22                   Snack Place                     NaN            NaN
# 23                        School       415 Broadview Ave        Toronto
# 24                   High School         371 Bloor St. W        Toronto
# 25                          Pool    181 Broadview Avenue        Toronto
# 26                          None      135-14800 Yonge St         Aurora
# 27                        School                     NaN            NaN
# 28                  Soccer Field     24 Bedford Park Ave        Toronto
# 29                        School                     NaN            NaN
#
#           lat        lng postalCode    state
# 0   43.828306 -79.308775        NaN       ON
# 1   43.835247 -79.307804        NaN       ON
# 2   43.831911 -79.309984        NaN       ON
# 3   43.783502 -79.444801    M2R 2N1       ON
# 4   43.803416 -79.444965    L4J 2P6       ON
# 5   43.709946 -79.428388    M5B 1T2       ON
# 6   43.867483 -79.363144        NaN       ON
# 7   43.763935 -79.402820    M2N 3C1  Ontario
# 8   43.754490 -79.350326        NaN       ON
# 9   43.789210 -79.417900        NaN       ON
# 10  43.816878 -79.229456    M1B 4Y6       ON
# 11  43.758972 -79.315605    M1R 1V5       ON
# 12  43.894553 -79.263375    L6E 1A3       ON
# 13  43.938602 -79.274865        NaN       ON
# 14  43.808889 -79.333649    M1W 2S7       ON
# 15  43.727457 -79.344325        NaN      NaN
# 16  43.814216 -79.444059        NaN       ON
# 17  43.899362 -79.443838    L4S 1H5       ON
# 18  43.736887 -79.218818    M1M 1R5       ON
# 19  43.850901 -79.511876    L6A 3Y4       ON
# 20  43.641185 -79.428628        NaN       ON
# 21  43.681208 -79.428296    M6C 1B5       ON
# 22  43.791149 -79.246043        NaN      NaN
# 23  43.666413 -79.352725    M4K 2M9       ON
# 24  43.667041 -79.401773    M5S 2R7       ON
# 25  43.661119 -79.350455    M4M 2G3       ON
# 26  43.988181 -79.464814    L4G 1N3       ON
# 27  43.657791 -79.438629        NaN      NaN
# 28  43.727192 -79.404945    M5M 1H9       ON
# 29  43.835959 -79.476362        NaN      NaN

# %%
df_school = school_clean_dataframe1.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_school
# Out:
#                                                  name  \
# 3   Eitz Chaim Day Schools - Administrative/Patric...
# 4         Eitz Chaim Day Schools - Spring Farm Branch
# 5           Eitz Chaim Day Schools - Viewmount Branch
# 11                     Beaches ITF Taekwon-Do Schools
# 12                Spirit of Math Schools Markham East
# 14                Amberson High School - South Campus
# 18                Best Driving Schools in Scarborough
# 19                     Spirit of Math Schools Vaughan
# 21                  Northern Karate Schools - Midtown
# 23                   Spirit of Math Schools The Beach
# 24                      University of Toronto Schools
# 25                               Felix's Swim Schools
# 28              Blessed Sacrament School Soccer Field
#
#                       categories                 address         city  \
# 3   General College & University       475 Patricia Ave.      Toronto
# 4              College Classroom      80 York Hill Blvd.      Toronto
# 5              Elementary School        1 Viewmount Ave.      Toronto
# 11             Martial Arts Dojo  2975 Victoria Park Ave      Toronto
# 12                Private School       9293 Markham Road      Markham
# 14                   High School    3470 Pharmacy Avenue      Toronto
# 18                Driving School      3464 kingston Road  Scarborough
# 19                Private School       9860 Keele Street      Vaughan
# 21             Martial Arts Dojo      756 St Clair Ave W      Toronto
# 23                        School       415 Broadview Ave      Toronto
# 24                   High School         371 Bloor St. W      Toronto
# 25                          Pool    181 Broadview Avenue      Toronto
# 28                  Soccer Field     24 Bedford Park Ave      Toronto
#
#           lat        lng postalCode state
# 3   43.783502 -79.444801    M2R 2N1    ON
# 4   43.803416 -79.444965    L4J 2P6    ON
# 5   43.709946 -79.428388    M5B 1T2    ON
# 11  43.758972 -79.315605    M1R 1V5    ON
# 12  43.894553 -79.263375    L6E 1A3    ON
# 14  43.808889 -79.333649    M1W 2S7    ON
# 18  43.736887 -79.218818    M1M 1R5    ON
# 19  43.850901 -79.511876    L6A 3Y4    ON
# 21  43.681208 -79.428296    M6C 1B5    ON
# 23  43.666413 -79.352725    M4K 2M9    ON
# 24  43.667041 -79.401773    M5S 2R7    ON
# 25  43.661119 -79.350455    M4M 2G3    ON
# 28  43.727192 -79.404945    M5M 1H9    ON

# %%
# search for Parks
search_query = 'communityParks'
radius = 300000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=UQREUQKVGIBHLFGEYOVZPNV0JPMTKRJEBHJHTHZGQUIL0CTU&client_secret=KXG4WQ0ZJSIFST0P4VOORPECWP54IZUH5LPRH5YTRNKVZ323&ll=43.828193,-79.3259721525424&v=20180604&query=communityParks&radius=300000&limit=30'

# %%
park_results = requests.get(url).json()
#results
park_results
# Out:
# {'meta': {'code': 200, 'requestId': '5d533fdca30619002cf02c97'},
#  'response': {'venues': [{'id': '4bcef464b6c49c741ddf9791',
#     'name': 'Toronto Chinese Community Church 多倫多華人基督教會',
#     'location': {'address': '100 Acadia Ave.',
#      'crossStreet': 'at Ferrier St.',
#      'lat': 43.821747139918386,
#      'lng': -79.32840009522823,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.821747139918386,
#        'lng': -79.32840009522823}],
#      'distance': 743,
#      'postalCode': 'L3R 5A2',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 Acadia Ave. (at Ferrier St.)',
#       'Markham ON L3R 5A2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4bda04093904a593bdad449e',
#     'name': "L'Amoreaux Community Recreation Centre",
#     'location': {'address': '2000 McNicoll Ave.',
#      'crossStreet': 'at Kennedy Rd.',
#      'lat': 43.81210616188243,
#      'lng': -79.3050972736739,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.81210616188243,
#        'lng': -79.3050972736739}],
#      'distance': 2453,
#      'postalCode': 'M1V 5E9',
#      'cc': 'CA',
#      'city': 'Scarborough',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2000 McNicoll Ave. (at Kennedy Rd.)',
#       'Scarborough ON M1V 5E9',
#       'Canada']},
#     'categories': [{'id': '4f4528bc4b90abdf24c9de85',
#       'name': 'Athletics & Sports',
#       'pluralName': 'Athletics & Sports',
#       'shortName': 'Athletics & Sports',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4b433b8bf964a52054dd25e3',
#     'name': 'Angus Glen Community Centre & Library',
#     'location': {'address': '3990 Major Mackenzie Dr. E',
#      'crossStreet': 'at Angus Glen Blvd.',
#      'lat': 43.89454811390253,
#      'lng': -79.33575768119384,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.89454811390253,
#        'lng': -79.33575768119384}],
#      'distance': 7428,
#      'postalCode': 'L6C 1P8',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['3990 Major Mackenzie Dr. E (at Angus Glen Blvd.)',
#       'Markham ON L6C 1P8',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a34',
#       'name': 'Community Center',
#       'pluralName': 'Community Centers',
#       'shortName': 'Community Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4af30a8bf964a5200cea21e3',
#     'name': 'Thornhill Community Centre',
#     'location': {'address': '7755 Bayview Ave.',
#      'crossStreet': 'at John St.',
#      'lat': 43.81957827072402,
#      'lng': -79.40050833817448,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.81957827072402,
#        'lng': -79.40050833817448}],
#      'distance': 6062,
#      'postalCode': 'L3T 4P1',
#      'cc': 'CA',
#      'city': 'Thornhill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7755 Bayview Ave. (at John St.)',
#       'Thornhill ON L3T 4P1',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a34',
#       'name': 'Community Center',
#       'pluralName': 'Community Centers',
#       'shortName': 'Community Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4d2ded6690cb236a9b476078',
#     'name': 'Old Unionville Library Community Centre',
#     'location': {'address': '15 Library Lane',
#      'lat': 43.870095,
#      'lng': -79.310559,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.870095,
#        'lng': -79.310559}],
#      'distance': 4825,
#      'postalCode': 'L3R 5T7',
#      'cc': 'CA',
#      'city': 'Unionville',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['15 Library Lane',
#       'Unionville ON L3R 5T7',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a34',
#       'name': 'Community Center',
#       'pluralName': 'Community Centers',
#       'shortName': 'Community Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4b6480d3f964a520c9b82ae3',
#     'name': 'Bayview Hill Community Centre & Pool',
#     'location': {'address': '114 Spadina Rd',
#      'crossStreet': 'Weldrick Rd E',
#      'lat': 43.86958817934623,
#      'lng': -79.40194312719932,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.86958817934623,
#        'lng': -79.40194312719932}],
#      'distance': 7644,
#      'postalCode': 'L4B 2Y9',
#      'cc': 'CA',
#      'city': 'Richmond Hill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['114 Spadina Rd (Weldrick Rd E)',
#       'Richmond Hill ON L4B 2Y9',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a34',
#       'name': 'Community Center',
#       'pluralName': 'Community Centers',
#       'shortName': 'Community Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4c75a88f604a3704ee658349',
#     'name': '16th Church/community Centre',
#     'location': {'lat': 43.85377671215733,
#      'lng': -79.41272257257366,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.85377671215733,
#        'lng': -79.41272257257366}],
#      'distance': 7524,
#      'cc': 'CA',
#      'state': 'Ontario',
#      'country': 'Canada',
#      'formattedAddress': ['Ontario', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4b90a821f964a520769333e3',
#     'name': 'Oriole Community Centre',
#     'location': {'address': '2975 Don Mills Road West',
#      'lat': 43.78152992719611,
#      'lng': -79.35211741273284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.78152992719611,
#        'lng': -79.35211741273284}],
#      'distance': 5603,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2975 Don Mills Road West', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e8941735',
#       'name': 'Baseball Field',
#       'pluralName': 'Baseball Fields',
#       'shortName': 'Baseball Field',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/baseballfield_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '50ba89a0e4b071d53086cc98',
#     'name': 'Cornell Community Centre & Library',
#     'location': {'address': '3201 Bur Oak Ave',
#      'crossStreet': 'at Church St',
#      'lat': 43.88482565504594,
#      'lng': -79.23028707504271,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.88482565504594,
#        'lng': -79.23028707504271}],
#      'distance': 9936,
#      'postalCode': 'L6B 0T2',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['3201 Bur Oak Ave (at Church St)',
#       'Markham ON L6B 0T2',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a34',
#       'name': 'Community Center',
#       'pluralName': 'Community Centers',
#       'shortName': 'Community Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4c0008dfca1920a1c1b8ed81',
#     'name': 'Agincourt Community Services Association',
#     'location': {'address': '4155 Sheppard Ave. East',
#      'crossStreet': 'Midland',
#      'lat': 43.78465407558168,
#      'lng': -79.28064437902866,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.78465407558168,
#        'lng': -79.28064437902866}],
#      'distance': 6062,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['4155 Sheppard Ave. East (Midland)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '5b0c0d3f98fbfc002cac2935',
#     'name': 'Langstaff Square Care Community',
#     'location': {'address': '170 Red Maple Rd',
#      'lat': 43.84472969999999,
#      'lng': -79.4250519,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.84472969999999,
#        'lng': -79.4250519}],
#      'distance': 8165,
#      'postalCode': 'L4B 4T8',
#      'cc': 'CA',
#      'city': 'Richmond Hill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['170 Red Maple Rd',
#       'Richmond Hill ON L4B 4T8',
#       'Canada']},
#     'categories': [{'id': '5032891291d4c4b30a586d68',
#       'name': 'Assisted Living',
#       'pluralName': 'Assisted Living',
#       'shortName': 'Assisted Living',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4d593d4f1d6cf04d173435fe',
#     'name': 'Central East Community Access Care (CECCAC)',
#     'location': {'address': '100 Consilium Pl.',
#      'crossStreet': 'at Corporate Dr.',
#      'lat': 43.776451,
#      'lng': -79.252857,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.776451,
#        'lng': -79.252857}],
#      'distance': 8226,
#      'postalCode': 'M1H 3E3',
#      'cc': 'CA',
#      'city': 'Scarborough',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 Consilium Pl. (at Corporate Dr.)',
#       'Scarborough ON M1H 3E3',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4c8ec764d2aea0934361d169',
#     'name': 'Markham Community Centre',
#     'location': {'crossStreet': 'Markham Rd and Hwy 7',
#      'lat': 43.87412476228143,
#      'lng': -79.25821122183827,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.87412476228143,
#        'lng': -79.25821122183827}],
#      'distance': 7465,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Markham ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f2931735',
#       'name': 'Performing Arts Venue',
#       'pluralName': 'Performing Arts Venues',
#       'shortName': 'Performing Arts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4b594731f964a520c18328e3',
#     'name': 'Garnet A. Williams Community Centre Gym',
#     'location': {'address': '501 Clark Ave West',
#      'crossStreet': 'Bathurst & Clark',
#      'lat': 43.80437884037752,
#      'lng': -79.44027286974573,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.80437884037752,
#        'lng': -79.44027286974573}],
#      'distance': 9556,
#      'postalCode': 'L4J 4E5',
#      'cc': 'CA',
#      'city': 'Thornhill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['501 Clark Ave West (Bathurst & Clark)',
#       'Thornhill ON L4J 4E5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4c470474c047be9ab1252f79',
#     'name': 'Rouge Woods Community Center',
#     'location': {'address': '110 Shirley Dr.',
#      'crossStreet': 'at Wayside Ave.',
#      'lat': 43.883743,
#      'lng': -79.404012,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.883743,
#        'lng': -79.404012}],
#      'distance': 8802,
#      'postalCode': 'L4S 2M5',
#      'cc': 'CA',
#      'city': 'Richmond Hill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['110 Shirley Dr. (at Wayside Ave.)',
#       'Richmond Hill ON L4S 2M5',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a34',
#       'name': 'Community Center',
#       'pluralName': 'Community Centers',
#       'shortName': 'Community Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4b5c6627f964a520032e29e3',
#     'name': 'Garnet A. Williams Community Centre',
#     'location': {'address': '501 Clark Ave. W',
#      'crossStreet': 'Clark and Atkinson Ave.',
#      'lat': 43.80456100581103,
#      'lng': -79.44000361686771,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.80456100581103,
#        'lng': -79.44000361686771}],
#      'distance': 9529,
#      'postalCode': 'L4J 4E5',
#      'cc': 'CA',
#      'city': 'Thornhill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['501 Clark Ave. W (Clark and Atkinson Ave.)',
#       'Thornhill ON L4J 4E5',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a34',
#       'name': 'Community Center',
#       'pluralName': 'Community Centers',
#       'shortName': 'Community Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4c1bade2eac020a1b33e45c2',
#     'name': 'Richvale Community Centre',
#     'location': {'address': '160 Avenue Road',
#      'lat': 43.853750944954115,
#      'lng': -79.44600392270242,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.853750944954115,
#        'lng': -79.44600392270242}],
#      'distance': 10048,
#      'cc': 'CA',
#      'city': 'York Regional Municipality',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['160 Avenue Road',
#       'York Regional Municipality ON',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a34',
#       'name': 'Community Center',
#       'pluralName': 'Community Centers',
#       'shortName': 'Community Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '525da052498e7cddab664ed3',
#     'name': 'Sakinah Community Centre',
#     'location': {'lat': 43.75240213930334,
#      'lng': -79.2875026222956,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.75240213930334,
#        'lng': -79.2875026222956}],
#      'distance': 8985,
#      'cc': 'CA',
#      'state': 'Ontario',
#      'country': 'Canada',
#      'formattedAddress': ['Ontario', 'Canada']},
#     'categories': [{'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'shortName': 'Non-Profit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4b511b46f964a520cb4227e3',
#     'name': 'Richmond Hill Christian Community Church 城北華人基督教會',
#     'location': {'address': '9670 Bayview Ave.',
#      'crossStreet': 'at Weldrick Rd.',
#      'lat': 43.8679412094729,
#      'lng': -79.41397949021498,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.8679412094729,
#        'lng': -79.41397949021498}],
#      'distance': 8336,
#      'postalCode': 'L4C 9X9',
#      'cc': 'CA',
#      'city': 'Richmond Hill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['9670 Bayview Ave. (at Weldrick Rd.)',
#       'Richmond Hill ON L4C 9X9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4e11a9d07d8b4d5613dc5462',
#     'name': 'Jack Goodard community centre',
#     'location': {'address': '929. Kennedy rd.',
#      'crossStreet': 'Lawrence',
#      'lat': 43.758361,
#      'lng': -79.260374,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.758361,
#        'lng': -79.260374}],
#      'distance': 9392,
#      'postalCode': 'M1K 2E8',
#      'cc': 'CA',
#      'city': 'Scarborough',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['929. Kennedy rd. (Lawrence)',
#       'Scarborough ON M1K 2E8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e4941735',
#       'name': 'Campground',
#       'pluralName': 'Campgrounds',
#       'shortName': 'Campground',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/campground_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4dff693fd22d48be8128b768',
#     'name': 'Reza Moridi MPP Community Office',
#     'location': {'address': '9891 Yonge Street',
#      'crossStreet': 'at Major Mackenzie Dr',
#      'lat': 43.868553,
#      'lng': -79.436086,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.868553,
#        'lng': -79.436086}],
#      'distance': 9916,
#      'postalCode': 'L4C 1V1',
#      'cc': 'CA',
#      'city': 'Richmond Hill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['9891 Yonge Street (at Major Mackenzie Dr)',
#       'Richmond Hill ON L4C 1V1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '52e67f2a498ed98e81b4db5b',
#     'name': 'Pakeer Sahadevan - Re/MAX Community Realty Inc.',
#     'location': {'address': '1265 Morningside Avenue',
#      'lat': 43.8025515,
#      'lng': -79.1994219,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.8025515,
#        'lng': -79.1994219}],
#      'distance': 10558,
#      'postalCode': 'M1B 3V9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1265 Morningside Avenue',
#       'Toronto ON M1B 3V9',
#       'Canada']},
#     'categories': [],
#     'venuePage': {'id': '505979460'},
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4c1805924ff90f4758cf0d49',
#     'name': 'North Thornhill Community Centre',
#     'location': {'address': '300 Pleasant Ridge Ave.',
#      'crossStreet': 'at Autumn Hill Boul.',
#      'lat': 43.832421690632465,
#      'lng': -79.47580575942993,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.832421690632465,
#        'lng': -79.47580575942993}],
#      'distance': 12041,
#      'postalCode': 'L4J 9B3',
#      'cc': 'CA',
#      'city': 'Thornhill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['300 Pleasant Ridge Ave. (at Autumn Hill Boul.)',
#       'Thornhill ON L4J 9B3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4e21c61122717a5245ce40a0',
#     'name': 'Earl Bales Community Centre',
#     'location': {'address': '4169 Bathurst St',
#      'lat': 43.75444702374619,
#      'lng': -79.43490964360893,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.75444702374619,
#        'lng': -79.43490964360893}],
#      'distance': 12000,
#      'postalCode': 'M3H 3P7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['4169 Bathurst St', 'Toronto ON M3H 3P7', 'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a34',
#       'name': 'Community Center',
#       'pluralName': 'Community Centers',
#       'shortName': 'Community Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4e08c998b0fbba5eee241d30',
#     'name': 'Flemingdon Community Centre',
#     'location': {'lat': 43.71768270281737,
#      'lng': -79.33104566755902,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.71768270281737,
#        'lng': -79.33104566755902}],
#      'distance': 12308,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4d99e0bbd1bca0903f9b76b4',
#     'name': 'Labour Community Services',
#     'location': {'address': '15 Gervais Drive, #603',
#      'crossStreet': 'Don Mills and Eglinton',
#      'lat': 43.722316,
#      'lng': -79.335247,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.722316,
#        'lng': -79.335247}],
#      'distance': 11809,
#      'postalCode': 'M3C 1Y8',
#      'cc': 'CA',
#      'city': 'North York',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['15 Gervais Drive, #603 (Don Mills and Eglinton)',
#       'North York ON M3C 1Y8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4f2343f7e4b0085e48c355db',
#     'name': 'Dufferin Clark Community Centre',
#     'location': {'address': '1441 Clark Avenue West',
#      'lat': 43.79613982083708,
#      'lng': -79.4711657746824,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.79613982083708,
#        'lng': -79.4711657746824}],
#      'distance': 12196,
#      'cc': 'CA',
#      'city': 'Vaughan',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1441 Clark Avenue West', 'Vaughan ON', 'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a34',
#       'name': 'Community Center',
#       'pluralName': 'Community Centers',
#       'shortName': 'Community Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4fc28446e4b058bc4894f39d',
#     'name': 'Oak Ridges Community Centre Fitness Studio',
#     'location': {'address': '12895 Bayview Avenue',
#      'crossStreet': 'Bethesda',
#      'lat': 43.94715006431003,
#      'lng': -79.42831007140907,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.94715006431003,
#        'lng': -79.42831007140907}],
#      'distance': 15580,
#      'cc': 'CA',
#      'city': 'Oak Ridges',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['12895 Bayview Avenue (Bethesda)',
#       'Oak Ridges ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4cad11d214c3370437e9f53b',
#     'name': 'TanenbaumCHAT (Community Hebrew Academy of Toronto)',
#     'location': {'address': '9600 Bathurst St.',
#      'crossStreet': 'at Marc Santi Blvd.',
#      'lat': 43.8542372637765,
#      'lng': -79.46210720335392,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.8542372637765,
#        'lng': -79.46210720335392}],
#      'distance': 11308,
#      'postalCode': 'L6A 3Z8',
#      'cc': 'CA',
#      'city': 'Vaughan',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['9600 Bathurst St. (at Marc Santi Blvd.)',
#       'Vaughan ON L6A 3Z8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'shortName': 'High School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4ea081799adf6524d2a2007a',
#     'name': 'YRP Community Safety Village',
#     'location': {'lat': 43.94433142547496,
#      'lng': -79.34084871315791,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.94433142547496,
#        'lng': -79.34084871315791}],
#      'distance': 12983,
#      'cc': 'CA',
#      'city': 'Gormley',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Gormley ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d12e941735',
#       'name': 'Police Station',
#       'pluralName': 'Police Stations',
#       'shortName': 'Police Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_policestation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
park_venues = park_results['response']['venues']

# tranform venues into a dataframe
park_venues = json_normalize(park_venues)
park_venues.head(10)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...    False
# 1  [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...    False
# 2  [{'id': '52e81612bcbc57f1066b7a34', 'name': 'C...    False
# 3  [{'id': '52e81612bcbc57f1066b7a34', 'name': 'C...    False
# 4  [{'id': '52e81612bcbc57f1066b7a34', 'name': 'C...    False
# 5  [{'id': '52e81612bcbc57f1066b7a34', 'name': 'C...    False
# 6  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...    False
# 7  [{'id': '4bf58dd8d48988d1e8941735', 'name': 'B...    False
# 8  [{'id': '52e81612bcbc57f1066b7a34', 'name': 'C...    False
# 9  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...    False
#
#                          id            location.address location.cc  \
# 0  4bcef464b6c49c741ddf9791             100 Acadia Ave.          CA
# 1  4bda04093904a593bdad449e          2000 McNicoll Ave.          CA
# 2  4b433b8bf964a52054dd25e3  3990 Major Mackenzie Dr. E          CA
# 3  4af30a8bf964a5200cea21e3           7755 Bayview Ave.          CA
# 4  4d2ded6690cb236a9b476078             15 Library Lane          CA
# 5  4b6480d3f964a520c9b82ae3              114 Spadina Rd          CA
# 6  4c75a88f604a3704ee658349                         NaN          CA
# 7  4b90a821f964a520769333e3    2975 Don Mills Road West          CA
# 8  50ba89a0e4b071d53086cc98            3201 Bur Oak Ave          CA
# 9  4c0008dfca1920a1c1b8ed81     4155 Sheppard Ave. East          CA
#
#    location.city location.country location.crossStreet  location.distance  \
# 0        Markham           Canada       at Ferrier St.                743
# 1    Scarborough           Canada       at Kennedy Rd.               2453
# 2        Markham           Canada  at Angus Glen Blvd.               7428
# 3      Thornhill           Canada          at John St.               6062
# 4     Unionville           Canada                  NaN               4825
# 5  Richmond Hill           Canada        Weldrick Rd E               7644
# 6            NaN           Canada                  NaN               7524
# 7        Toronto           Canada                  NaN               5603
# 8        Markham           Canada         at Church St               9936
# 9        Toronto           Canada              Midland               6062
#
#                            location.formattedAddress  \
# 0  [100 Acadia Ave. (at Ferrier St.), Markham ON ...
# 1  [2000 McNicoll Ave. (at Kennedy Rd.), Scarboro...
# 2  [3990 Major Mackenzie Dr. E (at Angus Glen Blv...
# 3  [7755 Bayview Ave. (at John St.), Thornhill ON...
# 4   [15 Library Lane, Unionville ON L3R 5T7, Canada]
# 5  [114 Spadina Rd (Weldrick Rd E), Richmond Hill...
# 6                                  [Ontario, Canada]
# 7     [2975 Don Mills Road West, Toronto ON, Canada]
# 8  [3201 Bur Oak Ave (at Church St), Markham ON L...
# 9  [4155 Sheppard Ave. East (Midland), Toronto ON...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.82174713991838...     43.821747
# 1  [{'label': 'display', 'lat': 43.81210616188243...     43.812106
# 2  [{'label': 'display', 'lat': 43.89454811390253...     43.894548
# 3  [{'label': 'display', 'lat': 43.81957827072402...     43.819578
# 4  [{'label': 'display', 'lat': 43.870095, 'lng':...     43.870095
# 5  [{'label': 'display', 'lat': 43.86958817934623...     43.869588
# 6  [{'label': 'display', 'lat': 43.85377671215733...     43.853777
# 7  [{'label': 'display', 'lat': 43.78152992719611...     43.781530
# 8  [{'label': 'display', 'lat': 43.88482565504594...     43.884826
# 9  [{'label': 'display', 'lat': 43.78465407558168...     43.784654
#
#    location.lng location.postalCode location.state  \
# 0    -79.328400             L3R 5A2             ON
# 1    -79.305097             M1V 5E9             ON
# 2    -79.335758             L6C 1P8             ON
# 3    -79.400508             L3T 4P1             ON
# 4    -79.310559             L3R 5T7             ON
# 5    -79.401943             L4B 2Y9             ON
# 6    -79.412723                 NaN        Ontario
# 7    -79.352117                 NaN             ON
# 8    -79.230287             L6B 0T2             ON
# 9    -79.280644                 NaN             ON
#
#                                          name    referralId venuePage.id
# 0  Toronto Chinese Community Church 多倫多華人基督教會  v-1565736924          NaN
# 1      L'Amoreaux Community Recreation Centre  v-1565736924          NaN
# 2       Angus Glen Community Centre & Library  v-1565736924          NaN
# 3                  Thornhill Community Centre  v-1565736924          NaN
# 4     Old Unionville Library Community Centre  v-1565736924          NaN
# 5        Bayview Hill Community Centre & Pool  v-1565736924          NaN
# 6                16th Church/community Centre  v-1565736924          NaN
# 7                     Oriole Community Centre  v-1565736924          NaN
# 8          Cornell Community Centre & Library  v-1565736924          NaN
# 9    Agincourt Community Services Association  v-1565736924          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location

park_venues_columns = ['name', 'categories'] + [col for col in park_venues.columns if col.startswith('location.')]+ ['id']
park_clean_dataframe = park_venues.loc[:,park_venues_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
park_clean_dataframe['categories'] = park_clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
park_clean_dataframe.columns = [column.split('.')[-1] for column in park_clean_dataframe.columns]

park_clean_dataframe.head(10)
# Out:
#                                          name          categories  \
# 0  Toronto Chinese Community Church 多倫多華人基督教會              Church
# 1      L'Amoreaux Community Recreation Centre  Athletics & Sports
# 2       Angus Glen Community Centre & Library    Community Center
# 3                  Thornhill Community Centre    Community Center
# 4     Old Unionville Library Community Centre    Community Center
# 5        Bayview Hill Community Centre & Pool    Community Center
# 6                16th Church/community Centre              Church
# 7                     Oriole Community Centre      Baseball Field
# 8          Cornell Community Centre & Library    Community Center
# 9    Agincourt Community Services Association            Building
#
#                       address  cc           city country          crossStreet  \
# 0             100 Acadia Ave.  CA        Markham  Canada       at Ferrier St.
# 1          2000 McNicoll Ave.  CA    Scarborough  Canada       at Kennedy Rd.
# 2  3990 Major Mackenzie Dr. E  CA        Markham  Canada  at Angus Glen Blvd.
# 3           7755 Bayview Ave.  CA      Thornhill  Canada          at John St.
# 4             15 Library Lane  CA     Unionville  Canada                  NaN
# 5              114 Spadina Rd  CA  Richmond Hill  Canada        Weldrick Rd E
# 6                         NaN  CA            NaN  Canada                  NaN
# 7    2975 Don Mills Road West  CA        Toronto  Canada                  NaN
# 8            3201 Bur Oak Ave  CA        Markham  Canada         at Church St
# 9     4155 Sheppard Ave. East  CA        Toronto  Canada              Midland
#
#    distance                                   formattedAddress  \
# 0       743  [100 Acadia Ave. (at Ferrier St.), Markham ON ...
# 1      2453  [2000 McNicoll Ave. (at Kennedy Rd.), Scarboro...
# 2      7428  [3990 Major Mackenzie Dr. E (at Angus Glen Blv...
# 3      6062  [7755 Bayview Ave. (at John St.), Thornhill ON...
# 4      4825   [15 Library Lane, Unionville ON L3R 5T7, Canada]
# 5      7644  [114 Spadina Rd (Weldrick Rd E), Richmond Hill...
# 6      7524                                  [Ontario, Canada]
# 7      5603     [2975 Don Mills Road West, Toronto ON, Canada]
# 8      9936  [3201 Bur Oak Ave (at Church St), Markham ON L...
# 9      6062  [4155 Sheppard Ave. East (Midland), Toronto ON...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.82174713991838...  43.821747 -79.328400
# 1  [{'label': 'display', 'lat': 43.81210616188243...  43.812106 -79.305097
# 2  [{'label': 'display', 'lat': 43.89454811390253...  43.894548 -79.335758
# 3  [{'label': 'display', 'lat': 43.81957827072402...  43.819578 -79.400508
# 4  [{'label': 'display', 'lat': 43.870095, 'lng':...  43.870095 -79.310559
# 5  [{'label': 'display', 'lat': 43.86958817934623...  43.869588 -79.401943
# 6  [{'label': 'display', 'lat': 43.85377671215733...  43.853777 -79.412723
# 7  [{'label': 'display', 'lat': 43.78152992719611...  43.781530 -79.352117
# 8  [{'label': 'display', 'lat': 43.88482565504594...  43.884826 -79.230287
# 9  [{'label': 'display', 'lat': 43.78465407558168...  43.784654 -79.280644
#
#   postalCode    state                        id
# 0    L3R 5A2       ON  4bcef464b6c49c741ddf9791
# 1    M1V 5E9       ON  4bda04093904a593bdad449e
# 2    L6C 1P8       ON  4b433b8bf964a52054dd25e3
# 3    L3T 4P1       ON  4af30a8bf964a5200cea21e3
# 4    L3R 5T7       ON  4d2ded6690cb236a9b476078
# 5    L4B 2Y9       ON  4b6480d3f964a520c9b82ae3
# 6        NaN  Ontario  4c75a88f604a3704ee658349
# 7        NaN       ON  4b90a821f964a520769333e3
# 8    L6B 0T2       ON  50ba89a0e4b071d53086cc98
# 9        NaN       ON  4c0008dfca1920a1c1b8ed81

# %%
# delete unnecessary columns
park_clean_dataframe1= park_clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
park_clean_dataframe1
# Out:
#                                                  name             categories  \
# 0          Toronto Chinese Community Church 多倫多華人基督教會                 Church
# 1              L'Amoreaux Community Recreation Centre     Athletics & Sports
# 2               Angus Glen Community Centre & Library       Community Center
# 3                          Thornhill Community Centre       Community Center
# 4             Old Unionville Library Community Centre       Community Center
# 5                Bayview Hill Community Centre & Pool       Community Center
# 6                        16th Church/community Centre                 Church
# 7                             Oriole Community Centre         Baseball Field
# 8                  Cornell Community Centre & Library       Community Center
# 9            Agincourt Community Services Association               Building
# 10                    Langstaff Square Care Community        Assisted Living
# 11        Central East Community Access Care (CECCAC)                   None
# 12                           Markham Community Centre  Performing Arts Venue
# 13            Garnet A. Williams Community Centre Gym   Gym / Fitness Center
# 14                       Rouge Woods Community Center       Community Center
# 15                Garnet A. Williams Community Centre       Community Center
# 16                          Richvale Community Centre       Community Center
# 17                           Sakinah Community Centre             Non-Profit
# 18  Richmond Hill Christian Community Church 城北華人基督教會                 Church
# 19                      Jack Goodard community centre             Campground
# 20                   Reza Moridi MPP Community Office        Coworking Space
# 21    Pakeer Sahadevan - Re/MAX Community Realty Inc.                   None
# 22                   North Thornhill Community Centre                    Gym
# 23                        Earl Bales Community Centre       Community Center
# 24                        Flemingdon Community Centre               Building
# 25                          Labour Community Services        Coworking Space
# 26                    Dufferin Clark Community Centre       Community Center
# 27         Oak Ridges Community Centre Fitness Studio   Gym / Fitness Center
# 28  TanenbaumCHAT (Community Hebrew Academy of Tor...            High School
# 29                       YRP Community Safety Village         Police Station
#
#                        address        lat        lng postalCode    state
# 0              100 Acadia Ave.  43.821747 -79.328400    L3R 5A2       ON
# 1           2000 McNicoll Ave.  43.812106 -79.305097    M1V 5E9       ON
# 2   3990 Major Mackenzie Dr. E  43.894548 -79.335758    L6C 1P8       ON
# 3            7755 Bayview Ave.  43.819578 -79.400508    L3T 4P1       ON
# 4              15 Library Lane  43.870095 -79.310559    L3R 5T7       ON
# 5               114 Spadina Rd  43.869588 -79.401943    L4B 2Y9       ON
# 6                          NaN  43.853777 -79.412723        NaN  Ontario
# 7     2975 Don Mills Road West  43.781530 -79.352117        NaN       ON
# 8             3201 Bur Oak Ave  43.884826 -79.230287    L6B 0T2       ON
# 9      4155 Sheppard Ave. East  43.784654 -79.280644        NaN       ON
# 10            170 Red Maple Rd  43.844730 -79.425052    L4B 4T8       ON
# 11           100 Consilium Pl.  43.776451 -79.252857    M1H 3E3       ON
# 12                         NaN  43.874125 -79.258211        NaN       ON
# 13          501 Clark Ave West  43.804379 -79.440273    L4J 4E5       ON
# 14             110 Shirley Dr.  43.883743 -79.404012    L4S 2M5       ON
# 15            501 Clark Ave. W  43.804561 -79.440004    L4J 4E5       ON
# 16             160 Avenue Road  43.853751 -79.446004        NaN       ON
# 17                         NaN  43.752402 -79.287503        NaN  Ontario
# 18           9670 Bayview Ave.  43.867941 -79.413979    L4C 9X9       ON
# 19            929. Kennedy rd.  43.758361 -79.260374    M1K 2E8       ON
# 20           9891 Yonge Street  43.868553 -79.436086    L4C 1V1       ON
# 21     1265 Morningside Avenue  43.802551 -79.199422    M1B 3V9       ON
# 22     300 Pleasant Ridge Ave.  43.832422 -79.475806    L4J 9B3       ON
# 23            4169 Bathurst St  43.754447 -79.434910    M3H 3P7       ON
# 24                         NaN  43.717683 -79.331046        NaN       ON
# 25      15 Gervais Drive, #603  43.722316 -79.335247    M3C 1Y8       ON
# 26      1441 Clark Avenue West  43.796140 -79.471166        NaN       ON
# 27        12895 Bayview Avenue  43.947150 -79.428310        NaN       ON
# 28           9600 Bathurst St.  43.854237 -79.462107    L6A 3Z8       ON
# 29                         NaN  43.944331 -79.340849        NaN       ON

# %%
df_park = park_clean_dataframe1.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_park
# Out:
#                                                  name            categories  \
# 0          Toronto Chinese Community Church 多倫多華人基督教會                Church
# 1              L'Amoreaux Community Recreation Centre    Athletics & Sports
# 2               Angus Glen Community Centre & Library      Community Center
# 3                          Thornhill Community Centre      Community Center
# 4             Old Unionville Library Community Centre      Community Center
# 5                Bayview Hill Community Centre & Pool      Community Center
# 8                  Cornell Community Centre & Library      Community Center
# 10                    Langstaff Square Care Community       Assisted Living
# 13            Garnet A. Williams Community Centre Gym  Gym / Fitness Center
# 14                       Rouge Woods Community Center      Community Center
# 15                Garnet A. Williams Community Centre      Community Center
# 18  Richmond Hill Christian Community Church 城北華人基督教會                Church
# 19                      Jack Goodard community centre            Campground
# 20                   Reza Moridi MPP Community Office       Coworking Space
# 22                   North Thornhill Community Centre                   Gym
# 23                        Earl Bales Community Centre      Community Center
# 25                          Labour Community Services       Coworking Space
# 28  TanenbaumCHAT (Community Hebrew Academy of Tor...           High School
#
#                        address        lat        lng postalCode state
# 0              100 Acadia Ave.  43.821747 -79.328400    L3R 5A2    ON
# 1           2000 McNicoll Ave.  43.812106 -79.305097    M1V 5E9    ON
# 2   3990 Major Mackenzie Dr. E  43.894548 -79.335758    L6C 1P8    ON
# 3            7755 Bayview Ave.  43.819578 -79.400508    L3T 4P1    ON
# 4              15 Library Lane  43.870095 -79.310559    L3R 5T7    ON
# 5               114 Spadina Rd  43.869588 -79.401943    L4B 2Y9    ON
# 8             3201 Bur Oak Ave  43.884826 -79.230287    L6B 0T2    ON
# 10            170 Red Maple Rd  43.844730 -79.425052    L4B 4T8    ON
# 13          501 Clark Ave West  43.804379 -79.440273    L4J 4E5    ON
# 14             110 Shirley Dr.  43.883743 -79.404012    L4S 2M5    ON
# 15            501 Clark Ave. W  43.804561 -79.440004    L4J 4E5    ON
# 18           9670 Bayview Ave.  43.867941 -79.413979    L4C 9X9    ON
# 19            929. Kennedy rd.  43.758361 -79.260374    M1K 2E8    ON
# 20           9891 Yonge Street  43.868553 -79.436086    L4C 1V1    ON
# 22     300 Pleasant Ridge Ave.  43.832422 -79.475806    L4J 9B3    ON
# 23            4169 Bathurst St  43.754447 -79.434910    M3H 3P7    ON
# 25      15 Gervais Drive, #603  43.722316 -79.335247    M3C 1Y8    ON
# 28           9600 Bathurst St.  43.854237 -79.462107    L6A 3Z8    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Community Center']
community_dataframe= df_park.loc[df_park['categories'].isin(array)]
community_dataframe
# Out:
#                                        name        categories  \
# 2     Angus Glen Community Centre & Library  Community Center
# 3                Thornhill Community Centre  Community Center
# 4   Old Unionville Library Community Centre  Community Center
# 5      Bayview Hill Community Centre & Pool  Community Center
# 8        Cornell Community Centre & Library  Community Center
# 14             Rouge Woods Community Center  Community Center
# 15      Garnet A. Williams Community Centre  Community Center
# 23              Earl Bales Community Centre  Community Center
#
#                        address        lat        lng postalCode state
# 2   3990 Major Mackenzie Dr. E  43.894548 -79.335758    L6C 1P8    ON
# 3            7755 Bayview Ave.  43.819578 -79.400508    L3T 4P1    ON
# 4              15 Library Lane  43.870095 -79.310559    L3R 5T7    ON
# 5               114 Spadina Rd  43.869588 -79.401943    L4B 2Y9    ON
# 8             3201 Bur Oak Ave  43.884826 -79.230287    L6B 0T2    ON
# 14             110 Shirley Dr.  43.883743 -79.404012    L4S 2M5    ON
# 15            501 Clark Ave. W  43.804561 -79.440004    L4J 4E5    ON
# 23            4169 Bathurst St  43.754447 -79.434910    M3H 3P7    ON

# %%
search_query = ''
radius = 100

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=UQREUQKVGIBHLFGEYOVZPNV0JPMTKRJEBHJHTHZGQUIL0CTU&client_secret=KXG4WQ0ZJSIFST0P4VOORPECWP54IZUH5LPRH5YTRNKVZ323&ll=43.828193,-79.3259721525424&v=20180604&query=&radius=100&limit=30'

# %%
results = requests.get(url).json()
#results
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d533fdc787dba00391e3f12'},
#  'response': {'venues': [{'id': '4e248475d16474063224c3b0',
#     'name': 'Monte Carlo Inn & Suites Downtown Markham',
#     'location': {'address': '7255 Warden Ave',
#      'lat': 43.8281552,
#      'lng': -79.3259549,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.8281552,
#        'lng': -79.3259549}],
#      'distance': 4,
#      'postalCode': 'L3R 1B4',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7255 Warden Ave', 'Markham ON L3R 1B4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4bf48a696a31d13a75f0952e',
#     'name': 'Subway',
#     'location': {'lat': 43.827569,
#      'lng': -79.326173,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.827569,
#        'lng': -79.326173}],
#      'distance': 71,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Markham ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '541f6dae498e7ff70560f1ac',
#     'name': 'Sweet House Dessert 金玉滿糖',
#     'location': {'address': '7750 Birchmount Road',
#      'crossStreet': '14th And Birchmount',
#      'lat': 43.841854664709054,
#      'lng': -79.32157358170592,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.841854664709054,
#        'lng': -79.32157358170592}],
#      'distance': 1561,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7750 Birchmount Road (14th And Birchmount)',
#       'Markham ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4df29b4622718759f81d09e4',
#     'name': 'Notabilia Education Centre 拔萃教育中心',
#     'location': {'address': '7170 Warden Ave',
#      'crossStreet': 'at Denison St',
#      'lat': 43.827005,
#      'lng': -79.326953,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.827005,
#        'lng': -79.326953}],
#      'distance': 153,
#      'postalCode': 'L3R 8B2',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7170 Warden Ave (at Denison St)',
#       'Markham ON L3R 8B2',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a46',
#       'name': 'Private School',
#       'pluralName': 'Private Schools',
#       'shortName': 'Private School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '55ef9530498e72b1a7eff0be',
#     'name': 'Makerwiz',
#     'location': {'address': '7271 Warden Ave',
#      'crossStreet': 'btwn McNabb St & Denison St',
#      'lat': 43.829227,
#      'lng': -79.326339,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.829227,
#        'lng': -79.326339}],
#      'distance': 118,
#      'postalCode': 'L3R 5X5',
#      'cc': 'CA',
#      'city': 'Richmond Hill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7271 Warden Ave (btwn McNabb St & Denison St)',
#       'Richmond Hill ON L3R 5X5',
#       'Canada']},
#     'categories': [{'id': '5453de49498eade8af355881',
#       'name': 'Business Service',
#       'pluralName': 'Business Services',
#       'shortName': 'Business Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4b22aa3af964a5205a4b24e3',
#     'name': 'Brookfield Homes',
#     'location': {'address': '7303 Warden Ave',
#      'lat': 43.828799619355216,
#      'lng': -79.32669392859273,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.828799619355216,
#        'lng': -79.32669392859273}],
#      'distance': 88,
#      'postalCode': 'L3R 5Y6',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7303 Warden Ave', 'Markham ON L3R 5Y6', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4c893a0697828cfa2894a2aa',
#     'name': 'Denison Vivastation',
#     'location': {'address': 'Warden Av',
#      'crossStreet': 'at Denison St',
#      'lat': 43.82795674254214,
#      'lng': -79.32617676783539,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82795674254214,
#        'lng': -79.32617676783539}],
#      'distance': 31,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Warden Av (at Denison St)',
#       'Markham ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4e2484c2d22d0a3f5a1666ce',
#     'name': 'Menaggio At Monte Carlo Inn',
#     'location': {'lat': 43.828051,
#      'lng': -79.326348,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.828051,
#        'lng': -79.326348}],
#      'distance': 34,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Markham ON', 'Canada']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4bc47fc92a89ef3b4e56f688',
#     'name': 'Max Media',
#     'location': {'lat': 43.825929,
#      'lng': -79.325787,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.825929,
#        'lng': -79.325787}],
#      'distance': 252,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4b317b47f964a520b60725e3',
#     'name': 'Wu Yi Villa',
#     'location': {'address': '4080 Steeles Ave East',
#      'lat': 43.830152,
#      'lng': -79.32724,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.830152,
#        'lng': -79.32724}],
#      'distance': 240,
#      'postalCode': 'L3R 4C3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['4080 Steeles Ave East',
#       'Toronto ON L3R 4C3',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4d28ff37d86aa090882f20c0',
#     'name': "Century 21 King's Quay Real Estate",
#     'location': {'address': '7300 Warden Avenue',
#      'crossStreet': 'at Denison St',
#      'lat': 43.82771592325008,
#      'lng': -79.32729721069335,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82771592325008,
#        'lng': -79.32729721069335}],
#      'distance': 118,
#      'postalCode': 'L3R 9Z6',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7300 Warden Avenue (at Denison St)',
#       'Markham ON L3R 9Z6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '5c9a61c8d03360002c23e9f1',
#     'name': 'Toronto Decorating Corporation',
#     'location': {'address': '236 Hood Rd.',
#      'lat': 43.825615,
#      'lng': -79.32806,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.825615,
#        'lng': -79.32806}],
#      'distance': 332,
#      'postalCode': 'L3R 3K8',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['236 Hood Rd.', 'Markham ON L3R 3K8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4c2b40282219c928233da448',
#     'name': 'Switchworks',
#     'location': {'lat': 43.829477,
#      'lng': -79.3288,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.829477,
#        'lng': -79.3288}],
#      'distance': 268,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4c2e252e4e132d7f1aa19ddf',
#     'name': "Jagger's Convenience",
#     'location': {'lat': 43.82708336444293,
#      'lng': -79.32596770203314,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82708336444293,
#        'lng': -79.32596770203314}],
#      'distance': 123,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4e472f79227128e1e8d67786',
#     'name': 'Utopia Dream Tea & More',
#     'location': {'address': '7170 Warden Ave. Unit 26-27',
#      'crossStreet': 'at Denison St.',
#      'lat': 43.826366426565336,
#      'lng': -79.32767961165847,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.826366426565336,
#        'lng': -79.32767961165847}],
#      'distance': 245,
#      'postalCode': 'L3R 8B4',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7170 Warden Ave. Unit 26-27 (at Denison St.)',
#       'Markham ON L3R 8B4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1dc931735',
#       'name': 'Tea Room',
#       'pluralName': 'Tea Rooms',
#       'shortName': 'Tea Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4c0f1557d64c0f476757295d',
#     'name': "Mac's",
#     'location': {'address': '1 Masseyfield Gate',
#      'lat': 43.82726699842418,
#      'lng': -79.32684659957886,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82726699842418,
#        'lng': -79.32684659957886}],
#      'distance': 124,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Masseyfield Gate', 'Markham ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '515b5728e4b01a7446ded844',
#     'name': 'Presidential gourmet',
#     'location': {'address': '7351 Victoria Patk',
#      'lat': 43.8284,
#      'lng': -79.3256,
#      'labeledLatLngs': [{'label': 'display', 'lat': 43.8284, 'lng': -79.3256}],
#      'distance': 37,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7351 Victoria Patk', 'Markham ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '526176ea11d2a41c253a55e6',
#     'name': 'Chatime Bubble Tea 日出茶太',
#     'location': {'address': '20 Gibson Dr',
#      'crossStreet': 'at Warden Ave',
#      'lat': 43.82434192411309,
#      'lng': -79.32606243237183,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82434192411309,
#        'lng': -79.32606243237183}],
#      'distance': 428,
#      'postalCode': 'L3R 8B5',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['20 Gibson Dr (at Warden Ave)',
#       'Markham ON L3R 8B5',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4e64da65b0fb188e8eb6fe95',
#     'name': 'Axiom Driving School',
#     'location': {'address': '7170 Warden Avenue Unit 1',
#      'lat': 43.827106,
#      'lng': -79.32684604173626,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.827106,
#        'lng': -79.32684604173626}],
#      'distance': 139,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7170 Warden Avenue Unit 1',
#       'Markham ON',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a42',
#       'name': 'Driving School',
#       'pluralName': 'Driving Schools',
#       'shortName': 'Driving School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '5a14d4cbe2d4aa3e17f01dea',
#     'name': 'The Alley',
#     'location': {'address': '30 Gibson Dr, Unit 118',
#      'lat': 43.82404843461901,
#      'lng': -79.32689531596755,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82404843461901,
#        'lng': -79.32689531596755}],
#      'distance': 467,
#      'postalCode': 'L3R 2S3',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['30 Gibson Dr, Unit 118',
#       'Markham ON L3R 2S3',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '461387049'},
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4c6723ebe1da1b8dab3d9dc3',
#     'name': 'Swagat',
#     'location': {'lat': 43.8312670706879,
#      'lng': -79.32759620218587,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.8312670706879,
#        'lng': -79.32759620218587}],
#      'distance': 366,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4b527180f964a520927d27e3',
#     'name': 'American Express Canada',
#     'location': {'address': '101 McNabb Street',
#      'crossStreet': 'Warden & Denison',
#      'lat': 43.832086695390394,
#      'lng': -79.325863168956,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.832086695390394,
#        'lng': -79.325863168956}],
#      'distance': 433,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['101 McNabb Street (Warden & Denison)',
#       'Markham ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '59bbfdf7ad910e5a03a7256c',
#     'name': 'DAGU RICE NOODLE Markham 大鼓米线',
#     'location': {'address': '20 Gibson Dr Unit 111A',
#      'crossStreet': 'at Warden Ave',
#      'lat': 43.82469335559991,
#      'lng': -79.32613044977187,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82469335559991,
#        'lng': -79.32613044977187}],
#      'distance': 389,
#      'postalCode': 'L3R 0M7',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['20 Gibson Dr Unit 111A (at Warden Ave)',
#       'Markham ON L3R 0M7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d1941735',
#       'name': 'Noodle House',
#       'pluralName': 'Noodle Houses',
#       'shortName': 'Noodles',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4e70a4881838f0daa0a65c5c',
#     'name': 'VentureLab',
#     'location': {'lat': 43.829155593518564,
#      'lng': -79.32634181945296,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.829155593518564,
#        'lng': -79.32634181945296}],
#      'distance': 111,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Markham ON', 'Canada']},
#     'categories': [{'id': '4d4b7105d754a06375d81259',
#       'name': 'Professional & Other Places',
#       'pluralName': 'Professional & Other Places',
#       'shortName': 'Professional',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4cf500db94feb1f742dd2aba',
#     'name': 'Markham Convergence Centre',
#     'location': {'lat': 43.82915611155236,
#      'lng': -79.32641884344105,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82915611155236,
#        'lng': -79.32641884344105}],
#      'distance': 113,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d19f941735',
#       'name': 'College Technology Building',
#       'pluralName': 'College Technology Buildings',
#       'shortName': 'Technology',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/collegeacademicbuildings_technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4fc791e6e4b012a19d831817',
#     'name': 'Combined Insurance',
#     'location': {'lat': 43.82752341853966,
#      'lng': -79.3271615714855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82752341853966,
#        'lng': -79.3271615714855}],
#      'distance': 121,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4cf7eb69665854810264d198',
#     'name': 'Amplifi',
#     'location': {'address': '7271 warden ave',
#      'lat': 43.82888459485115,
#      'lng': -79.3264463519928,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82888459485115,
#        'lng': -79.3264463519928}],
#      'distance': 85,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7271 warden ave', 'Markham ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '52a630cd498e84b31d5de596',
#     'name': 'Printloft',
#     'location': {'address': '7170 Warden Ave',
#      'lat': 43.82722854614258,
#      'lng': -79.32723999023438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82722854614258,
#        'lng': -79.32723999023438}],
#      'distance': 147,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7170 Warden Ave', 'Markham ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fb941735',
#       'name': 'Hobby Shop',
#       'pluralName': 'Hobby Shops',
#       'shortName': 'Hobbies',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hobbyshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '4ecbcd5c0e011bec7ab88ed9',
#     'name': 'Lyreco',
#     'location': {'address': '7303 Warden Ave',
#      'lat': 43.82996395034917,
#      'lng': -79.32684797592269,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.82996395034917,
#        'lng': -79.32684797592269}],
#      'distance': 209,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7303 Warden Ave', 'Markham ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False},
#    {'id': '55f2da53498e9048757e9225',
#     'name': 'Pharmaceutical Innovation Ltd',
#     'location': {'address': '7271 Warden Avenue',
#      'lat': 43.829111,
#      'lng': -79.3267,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.829111,
#        'lng': -79.3267}],
#      'distance': 117,
#      'postalCode': 'L3R 5X5',
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['7271 Warden Avenue',
#       'Markham ON L3R 5X5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565736924',
#     'hasPerk': False}],
#   'confident': True}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head(20)
# Out:
#                                            categories  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 2   [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...    False
# 3   [{'id': '52e81612bcbc57f1066b7a46', 'name': 'P...    False
# 4   [{'id': '5453de49498eade8af355881', 'name': 'B...    False
# 5   [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 6   [{'id': '4bf58dd8d48988d1fe931735', 'name': 'B...    False
# 7   [{'id': '4d4b7105d754a06374d81259', 'name': 'F...    False
# 8                                                  []    False
# 9                                                  []    False
# 10  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 11  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 12  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 13  [{'id': '4bf58dd8d48988d1ff941735', 'name': 'M...    False
# 14  [{'id': '4bf58dd8d48988d1dc931735', 'name': 'T...    False
# 15  [{'id': '4bf58dd8d48988d1ff941735', 'name': 'M...    False
# 16  [{'id': '4bf58dd8d48988d171941735', 'name': 'E...    False
# 17  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...    False
# 18  [{'id': '52e81612bcbc57f1066b7a42', 'name': 'D...    False
# 19  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...    False
#
#                           id             location.address location.cc  \
# 0   4e248475d16474063224c3b0              7255 Warden Ave          CA
# 1   4bf48a696a31d13a75f0952e                          NaN          CA
# 2   541f6dae498e7ff70560f1ac         7750 Birchmount Road          CA
# 3   4df29b4622718759f81d09e4              7170 Warden Ave          CA
# 4   55ef9530498e72b1a7eff0be              7271 Warden Ave          CA
# 5   4b22aa3af964a5205a4b24e3              7303 Warden Ave          CA
# 6   4c893a0697828cfa2894a2aa                    Warden Av          CA
# 7   4e2484c2d22d0a3f5a1666ce                          NaN          CA
# 8   4bc47fc92a89ef3b4e56f688                          NaN          CA
# 9   4b317b47f964a520b60725e3        4080 Steeles Ave East          CA
# 10  4d28ff37d86aa090882f20c0           7300 Warden Avenue          CA
# 11  5c9a61c8d03360002c23e9f1                 236 Hood Rd.          CA
# 12  4c2b40282219c928233da448                          NaN          CA
# 13  4c2e252e4e132d7f1aa19ddf                          NaN          CA
# 14  4e472f79227128e1e8d67786  7170 Warden Ave. Unit 26-27          CA
# 15  4c0f1557d64c0f476757295d           1 Masseyfield Gate          CA
# 16  515b5728e4b01a7446ded844           7351 Victoria Patk          CA
# 17  526176ea11d2a41c253a55e6                 20 Gibson Dr          CA
# 18  4e64da65b0fb188e8eb6fe95    7170 Warden Avenue Unit 1          CA
# 19  5a14d4cbe2d4aa3e17f01dea       30 Gibson Dr, Unit 118          CA
#
#     location.city location.country         location.crossStreet  \
# 0         Markham           Canada                          NaN
# 1         Markham           Canada                          NaN
# 2         Markham           Canada          14th And Birchmount
# 3         Markham           Canada                at Denison St
# 4   Richmond Hill           Canada  btwn McNabb St & Denison St
# 5         Markham           Canada                          NaN
# 6         Markham           Canada                at Denison St
# 7         Markham           Canada                          NaN
# 8             NaN           Canada                          NaN
# 9         Toronto           Canada                          NaN
# 10        Markham           Canada                at Denison St
# 11        Markham           Canada                          NaN
# 12            NaN           Canada                          NaN
# 13            NaN           Canada                          NaN
# 14        Markham           Canada               at Denison St.
# 15        Markham           Canada                          NaN
# 16        Markham           Canada                          NaN
# 17        Markham           Canada                at Warden Ave
# 18        Markham           Canada                          NaN
# 19        Markham           Canada                          NaN
#
#     location.distance                          location.formattedAddress  \
# 0                   4      [7255 Warden Ave, Markham ON L3R 1B4, Canada]
# 1                  71                               [Markham ON, Canada]
# 2                1561  [7750 Birchmount Road (14th And Birchmount), M...
# 3                 153  [7170 Warden Ave (at Denison St), Markham ON L...
# 4                 118  [7271 Warden Ave (btwn McNabb St & Denison St)...
# 5                  88      [7303 Warden Ave, Markham ON L3R 5Y6, Canada]
# 6                  31    [Warden Av (at Denison St), Markham ON, Canada]
# 7                  34                               [Markham ON, Canada]
# 8                 252                                           [Canada]
# 9                 240  [4080 Steeles Ave East, Toronto ON L3R 4C3, Ca...
# 10                118  [7300 Warden Avenue (at Denison St), Markham O...
# 11                332         [236 Hood Rd., Markham ON L3R 3K8, Canada]
# 12                268                                           [Canada]
# 13                123                                           [Canada]
# 14                245  [7170 Warden Ave. Unit 26-27 (at Denison St.),...
# 15                124           [1 Masseyfield Gate, Markham ON, Canada]
# 16                 37           [7351 Victoria Patk, Markham ON, Canada]
# 17                428  [20 Gibson Dr (at Warden Ave), Markham ON L3R ...
# 18                139    [7170 Warden Avenue Unit 1, Markham ON, Canada]
# 19                467  [30 Gibson Dr, Unit 118, Markham ON L3R 2S3, C...
#
#                               location.labeledLatLngs  location.lat  \
# 0   [{'label': 'display', 'lat': 43.8281552, 'lng'...     43.828155
# 1   [{'label': 'display', 'lat': 43.827569, 'lng':...     43.827569
# 2   [{'label': 'display', 'lat': 43.84185466470905...     43.841855
# 3   [{'label': 'display', 'lat': 43.827005, 'lng':...     43.827005
# 4   [{'label': 'display', 'lat': 43.829227, 'lng':...     43.829227
# 5   [{'label': 'display', 'lat': 43.82879961935521...     43.828800
# 6   [{'label': 'display', 'lat': 43.82795674254214...     43.827957
# 7   [{'label': 'display', 'lat': 43.828051, 'lng':...     43.828051
# 8   [{'label': 'display', 'lat': 43.825929, 'lng':...     43.825929
# 9   [{'label': 'display', 'lat': 43.830152, 'lng':...     43.830152
# 10  [{'label': 'display', 'lat': 43.82771592325008...     43.827716
# 11  [{'label': 'display', 'lat': 43.825615, 'lng':...     43.825615
# 12  [{'label': 'display', 'lat': 43.829477, 'lng':...     43.829477
# 13  [{'label': 'display', 'lat': 43.82708336444293...     43.827083
# 14  [{'label': 'display', 'lat': 43.82636642656533...     43.826366
# 15  [{'label': 'display', 'lat': 43.82726699842418...     43.827267
# 16  [{'label': 'display', 'lat': 43.8284, 'lng': -...     43.828400
# 17  [{'label': 'display', 'lat': 43.82434192411309...     43.824342
# 18  [{'label': 'display', 'lat': 43.827106, 'lng':...     43.827106
# 19  [{'label': 'display', 'lat': 43.82404843461901...     43.824048
#
#     location.lng location.postalCode location.state  \
# 0     -79.325955             L3R 1B4             ON
# 1     -79.326173                 NaN             ON
# 2     -79.321574                 NaN             ON
# 3     -79.326953             L3R 8B2             ON
# 4     -79.326339             L3R 5X5             ON
# 5     -79.326694             L3R 5Y6             ON
# 6     -79.326177                 NaN             ON
# 7     -79.326348                 NaN             ON
# 8     -79.325787                 NaN            NaN
# 9     -79.327240             L3R 4C3             ON
# 10    -79.327297             L3R 9Z6             ON
# 11    -79.328060             L3R 3K8             ON
# 12    -79.328800                 NaN            NaN
# 13    -79.325968                 NaN            NaN
# 14    -79.327680             L3R 8B4             ON
# 15    -79.326847                 NaN             ON
# 16    -79.325600                 NaN             ON
# 17    -79.326062             L3R 8B5             ON
# 18    -79.326846                 NaN             ON
# 19    -79.326895             L3R 2S3             ON
#
#                                          name    referralId venuePage.id
# 0   Monte Carlo Inn & Suites Downtown Markham  v-1565736924          NaN
# 1                                      Subway  v-1565736924          NaN
# 2                    Sweet House Dessert 金玉滿糖  v-1565736924          NaN
# 3           Notabilia Education Centre 拔萃教育中心  v-1565736924          NaN
# 4                                    Makerwiz  v-1565736924          NaN
# 5                            Brookfield Homes  v-1565736924          NaN
# 6                         Denison Vivastation  v-1565736924          NaN
# 7                 Menaggio At Monte Carlo Inn  v-1565736924          NaN
# 8                                   Max Media  v-1565736924          NaN
# 9                                 Wu Yi Villa  v-1565736924          NaN
# 10         Century 21 King's Quay Real Estate  v-1565736924          NaN
# 11             Toronto Decorating Corporation  v-1565736924          NaN
# 12                                Switchworks  v-1565736924          NaN
# 13                       Jagger's Convenience  v-1565736924          NaN
# 14                    Utopia Dream Tea & More  v-1565736924          NaN
# 15                                      Mac's  v-1565736924          NaN
# 16                       Presidential gourmet  v-1565736924          NaN
# 17                    Chatime Bubble Tea 日出茶太  v-1565736924          NaN
# 18                       Axiom Driving School  v-1565736924          NaN
# 19                                  The Alley  v-1565736924    461387049

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                         name        categories  \
# 0  Monte Carlo Inn & Suites Downtown Markham             Hotel
# 1                                     Subway    Sandwich Place
# 2                   Sweet House Dessert 金玉滿糖      Dessert Shop
# 3          Notabilia Education Centre 拔萃教育中心    Private School
# 4                                   Makerwiz  Business Service
#
#                 address  cc           city country  \
# 0       7255 Warden Ave  CA        Markham  Canada
# 1                   NaN  CA        Markham  Canada
# 2  7750 Birchmount Road  CA        Markham  Canada
# 3       7170 Warden Ave  CA        Markham  Canada
# 4       7271 Warden Ave  CA  Richmond Hill  Canada
#
#                    crossStreet  distance  \
# 0                          NaN         4
# 1                          NaN        71
# 2          14th And Birchmount      1561
# 3                at Denison St       153
# 4  btwn McNabb St & Denison St       118
#
#                                     formattedAddress  \
# 0      [7255 Warden Ave, Markham ON L3R 1B4, Canada]
# 1                               [Markham ON, Canada]
# 2  [7750 Birchmount Road (14th And Birchmount), M...
# 3  [7170 Warden Ave (at Denison St), Markham ON L...
# 4  [7271 Warden Ave (btwn McNabb St & Denison St)...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.8281552, 'lng'...  43.828155 -79.325955
# 1  [{'label': 'display', 'lat': 43.827569, 'lng':...  43.827569 -79.326173
# 2  [{'label': 'display', 'lat': 43.84185466470905...  43.841855 -79.321574
# 3  [{'label': 'display', 'lat': 43.827005, 'lng':...  43.827005 -79.326953
# 4  [{'label': 'display', 'lat': 43.829227, 'lng':...  43.829227 -79.326339
#
#   postalCode state                        id
# 0    L3R 1B4    ON  4e248475d16474063224c3b0
# 1        NaN    ON  4bf48a696a31d13a75f0952e
# 2        NaN    ON  541f6dae498e7ff70560f1ac
# 3    L3R 8B2    ON  4df29b4622718759f81d09e4
# 4    L3R 5X5    ON  55ef9530498e72b1a7eff0be

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','state', 'id'], axis=1)
clean_dataframe2
# Out:
#                                          name                   categories  \
# 0   Monte Carlo Inn & Suites Downtown Markham                        Hotel
# 1                                      Subway               Sandwich Place
# 2                    Sweet House Dessert 金玉滿糖                 Dessert Shop
# 3           Notabilia Education Centre 拔萃教育中心               Private School
# 4                                    Makerwiz             Business Service
# 5                            Brookfield Homes                       Office
# 6                         Denison Vivastation                  Bus Station
# 7                 Menaggio At Monte Carlo Inn                         Food
# 8                                   Max Media                         None
# 9                                 Wu Yi Villa                         None
# 10         Century 21 King's Quay Real Estate                       Office
# 11             Toronto Decorating Corporation                       Office
# 12                                Switchworks                       Office
# 13                       Jagger's Convenience           Miscellaneous Shop
# 14                    Utopia Dream Tea & More                     Tea Room
# 15                                      Mac's           Miscellaneous Shop
# 16                       Presidential gourmet                  Event Space
# 17                    Chatime Bubble Tea 日出茶太              Bubble Tea Shop
# 18                       Axiom Driving School               Driving School
# 19                                  The Alley              Bubble Tea Shop
# 20                                     Swagat                  Event Space
# 21                    American Express Canada                       Office
# 22              DAGU RICE NOODLE Markham 大鼓米线                 Noodle House
# 23                                 VentureLab  Professional & Other Places
# 24                 Markham Convergence Centre  College Technology Building
# 25                         Combined Insurance                     Building
# 26                                    Amplifi                       Office
# 27                                  Printloft                   Hobby Shop
# 28                                     Lyreco                       Office
# 29              Pharmaceutical Innovation Ltd                       Office
#
#                         address        lat        lng postalCode
# 0               7255 Warden Ave  43.828155 -79.325955    L3R 1B4
# 1                           NaN  43.827569 -79.326173        NaN
# 2          7750 Birchmount Road  43.841855 -79.321574        NaN
# 3               7170 Warden Ave  43.827005 -79.326953    L3R 8B2
# 4               7271 Warden Ave  43.829227 -79.326339    L3R 5X5
# 5               7303 Warden Ave  43.828800 -79.326694    L3R 5Y6
# 6                     Warden Av  43.827957 -79.326177        NaN
# 7                           NaN  43.828051 -79.326348        NaN
# 8                           NaN  43.825929 -79.325787        NaN
# 9         4080 Steeles Ave East  43.830152 -79.327240    L3R 4C3
# 10           7300 Warden Avenue  43.827716 -79.327297    L3R 9Z6
# 11                 236 Hood Rd.  43.825615 -79.328060    L3R 3K8
# 12                          NaN  43.829477 -79.328800        NaN
# 13                          NaN  43.827083 -79.325968        NaN
# 14  7170 Warden Ave. Unit 26-27  43.826366 -79.327680    L3R 8B4
# 15           1 Masseyfield Gate  43.827267 -79.326847        NaN
# 16           7351 Victoria Patk  43.828400 -79.325600        NaN
# 17                 20 Gibson Dr  43.824342 -79.326062    L3R 8B5
# 18    7170 Warden Avenue Unit 1  43.827106 -79.326846        NaN
# 19       30 Gibson Dr, Unit 118  43.824048 -79.326895    L3R 2S3
# 20                          NaN  43.831267 -79.327596        NaN
# 21            101 McNabb Street  43.832087 -79.325863        NaN
# 22       20 Gibson Dr Unit 111A  43.824693 -79.326130    L3R 0M7
# 23                          NaN  43.829156 -79.326342        NaN
# 24                          NaN  43.829156 -79.326419        NaN
# 25                          NaN  43.827523 -79.327162        NaN
# 26              7271 warden ave  43.828885 -79.326446        NaN
# 27              7170 Warden Ave  43.827229 -79.327240        NaN
# 28              7303 Warden Ave  43.829964 -79.326848        NaN
# 29           7271 Warden Avenue  43.829111 -79.326700    L3R 5X5

# %%
clean_dataframe2 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe2
# Out:
#                                          name        categories  \
# 0   Monte Carlo Inn & Suites Downtown Markham             Hotel
# 3           Notabilia Education Centre 拔萃教育中心    Private School
# 4                                    Makerwiz  Business Service
# 5                            Brookfield Homes            Office
# 10         Century 21 King's Quay Real Estate            Office
# 11             Toronto Decorating Corporation            Office
# 14                    Utopia Dream Tea & More          Tea Room
# 17                    Chatime Bubble Tea 日出茶太   Bubble Tea Shop
# 19                                  The Alley   Bubble Tea Shop
# 22              DAGU RICE NOODLE Markham 大鼓米线      Noodle House
# 29              Pharmaceutical Innovation Ltd            Office
#
#                         address        lat        lng postalCode
# 0               7255 Warden Ave  43.828155 -79.325955    L3R 1B4
# 3               7170 Warden Ave  43.827005 -79.326953    L3R 8B2
# 4               7271 Warden Ave  43.829227 -79.326339    L3R 5X5
# 5               7303 Warden Ave  43.828800 -79.326694    L3R 5Y6
# 10           7300 Warden Avenue  43.827716 -79.327297    L3R 9Z6
# 11                 236 Hood Rd.  43.825615 -79.328060    L3R 3K8
# 14  7170 Warden Ave. Unit 26-27  43.826366 -79.327680    L3R 8B4
# 17                 20 Gibson Dr  43.824342 -79.326062    L3R 8B5
# 19       30 Gibson Dr, Unit 118  43.824048 -79.326895    L3R 2S3
# 22       20 Gibson Dr Unit 111A  43.824693 -79.326130    L3R 0M7
# 29           7271 Warden Avenue  43.829111 -79.326700    L3R 5X5

# %%
clean_dataframe2.groupby('categories').count()
# Out:
#                   name  address  lat  lng  postalCode
# categories
# Bubble Tea Shop      2        2    2    2           2
# Business Service     1        1    1    1           1
# Hotel                1        1    1    1           1
# Noodle House         1        1    1    1           1
# Office               4        4    4    4           4
# Private School       1        1    1    1           1
# Tea Room             1        1    1    1           1

# %%
print('There are {} uniques categories.'.format(len(clean_dataframe2['categories'].unique())))
# Out:
# There are 7 uniques categories.

# %%
clean_dataframe2.shape
# Out:
# (11, 6)

# %%
num_top_venues = 6

for hood in clean_dataframe2['name']:
    print("----"+hood+"----")
    temp = clean_dataframe2[clean_dataframe2['name'] == hood].T.reset_index()
    temp.columns = ['Name','Under']
    temp = temp.iloc[1:]
    temp['Under'] = temp['Under'].astype(str,float)
    temp = temp.round({'freq': 5})
    print(temp.sort_values('Under', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Monte Carlo Inn & Suites Downtown Markham----
#          Name            Under
# 0  postalCode          L3R 1B4
# 1  categories            Hotel
# 2     address  7255 Warden Ave
# 3         lat       43.8281552
# 4         lng      -79.3259549
#
#
# ----Notabilia Education Centre 拔萃教育中心----
#          Name            Under
# 0  categories   Private School
# 1  postalCode          L3R 8B2
# 2     address  7170 Warden Ave
# 3         lat        43.827005
# 4         lng       -79.326953
#
#
# ----Makerwiz----
#          Name             Under
# 0  postalCode           L3R 5X5
# 1  categories  Business Service
# 2     address   7271 Warden Ave
# 3         lat         43.829227
# 4         lng        -79.326339
#
#
# ----Brookfield Homes----
#          Name               Under
# 0  categories              Office
# 1  postalCode             L3R 5Y6
# 2     address     7303 Warden Ave
# 3         lat  43.828799619355216
# 4         lng  -79.32669392859273
#
#
# ----Century 21 King's Quay Real Estate----
#          Name               Under
# 0  categories              Office
# 1  postalCode             L3R 9Z6
# 2     address  7300 Warden Avenue
# 3         lat   43.82771592325008
# 4         lng  -79.32729721069335
#
#
# ----Toronto Decorating Corporation----
#          Name         Under
# 0  categories        Office
# 1  postalCode       L3R 3K8
# 2         lat     43.825615
# 3     address  236 Hood Rd.
# 4         lng     -79.32806
#
#
# ----Utopia Dream Tea & More----
#          Name                        Under
# 0  categories                     Tea Room
# 1  postalCode                      L3R 8B4
# 2     address  7170 Warden Ave. Unit 26-27
# 3         lat           43.826366426565336
# 4         lng           -79.32767961165847
#
#
# ----Chatime Bubble Tea 日出茶太----
#          Name               Under
# 0  postalCode             L3R 8B5
# 1  categories     Bubble Tea Shop
# 2         lat   43.82434192411309
# 3     address        20 Gibson Dr
# 4         lng  -79.32606243237183
#
#
# ----The Alley----
#          Name                   Under
# 0  postalCode                 L3R 2S3
# 1  categories         Bubble Tea Shop
# 2         lat       43.82404843461901
# 3     address  30 Gibson Dr, Unit 118
# 4         lng      -79.32689531596755
#
#
# ----DAGU RICE NOODLE Markham 大鼓米线----
#          Name                   Under
# 0  categories            Noodle House
# 1  postalCode                 L3R 0M7
# 2         lat       43.82469335559991
# 3     address  20 Gibson Dr Unit 111A
# 4         lng      -79.32613044977187
#
#
# ----Pharmaceutical Innovation Ltd----
#          Name               Under
# 0  categories              Office
# 1  postalCode             L3R 5X5
# 2     address  7271 Warden Avenue
# 3         lat           43.829111
# 4         lng            -79.3267

# %% [markdown]
# Looking good. So now, we have all the information in area within few kilometers from the Downtown Markham, and we know Downtown Markham in under Developing Stage with numerous multicultural restaurant and people! We also know various parts of city with schools and housing developing and best community centers for children and seniors
#
# This concludes the data gathering phase - we are now ready to use this data for analysis to produce the report on optimal locations for a start high tech company in Markham location!

# %% [markdown]
# # Methodology <a name="methodology"></a>

# %% [markdown]
# In this project, our effort is to detecting areas in facilities around Downtown Markham for a startup companies to have their location as Markham. In order to facilitate, the Employees who located in the Markham and around not relocated for the job reason leaving behind their families. As the Markham has neighbor town, which has best schools, and Universities, which produces best talents as well.
#
#  First steps I have collected the date location Longitude and Latitude of the Downtown Markham with radius of 300000 collected the Neighborhood community parks, Schools, Hotels Business Services, and office locations. Grouping the Venues under Categories with available data.
#
# Second, step in our analysis there more facilities available to facilitate the Startup Tech companies its advantage for the companies to explore and establish in this area.
#
#  Final Steps focus on the Area under Developing and Construction of the City particularly the Downtown Markham. As it is going to be the High-tech Entrainment Town of the City Facilities for the Restaurant, Transportation, Schools Community Center, Gym etc., within and around 30kms range.

# %% [markdown]
# # Analysis <a name="analysis"></a>

# %% [markdown]
# Let us create a map / density of Schools Shopping Hotels and try to extract some meaningful info from that.  On our map and a few circles indicating distance of 1km, 2km and 3km in and around Downtown Markham

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
Tech_map = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, name, categories, address in zip(community_dataframe['lat'], community_dataframe['lng'], 
                                           community_dataframe['name'], community_dataframe['categories'],\
                                           community_dataframe['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
    location=[lat, lng],
    popup=folium.Popup(max_width=15)) .add_to(Tech_map),
    
for lat, lng, name, categories, address in zip(community_dataframe['lat'],community_dataframe['lng'], 
                                           community_dataframe['name'], community_dataframe['categories'],\
                                              community_dataframe['address']):
    
    folium.Marker([lat, lng],icon=folium.Icon(color='blue',icon='shopping-cart')
              ).add_to(Tech_map)

for lat, lng, name, categories, address in zip(clean_dataframe2['lat'],clean_dataframe2['lng'], 
                                          clean_dataframe2['name'],clean_dataframe2['categories'],\
                                              clean_dataframe2['address']):
    
    folium.Marker([lat, lng],icon=folium.Icon(color='green',icon='glass')
              ).add_to(Tech_map)

for lat, lng, name, categories, address in zip(df_school['lat'],df_school['lng'], 
                                           df_school['name'], df_school['categories'],\
                                              df_school['address']):
    folium.Marker([lat, lng],icon=folium.Icon(icon="graduation-cap", prefix="fa")
              ).add_to(Tech_map)
    

Tech_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
rest_map = folium.Map(location=[latitude, longitude], zoom_start=15)
for lat, lng, name, categories, address in zip(clean_dataframe2['lat'],clean_dataframe2['lng'], 
                                           clean_dataframe2['name'], clean_dataframe2['categories'],\
                                             clean_dataframe2['address']):
    folium.Marker([lat, lng],icon=folium.Icon(icon="home", prefix="fa")
                                              
              ).add_to(rest_map)
    

rest_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lat, lon = 43.828193, -79.3259721525424
zoom_start = 10

m = folium.Map(
    location=[lat, lon],
    tiles='Cartodb Positron',
    zoom_start=zoom_start
)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Results and Discussion <a name="results"></a>

# %% [markdown]
# Our analysis shows that although there are lots of potential for any startup tech companies within 300 thousand radius of Downtown Markham and the City of Markham developing high range Luxury Condominium and Business Parks and DT Markham fairly close to city center travel time connecting with the Highways are closer to the city’s Business Parks. Closeness to city center, strong socio-economic dynamics and  density.
# After directing our attention to this, more narrow area of interest.
#  Location, which has not only no nearby competition but also other factors taken into account and all other relevant conditions met.

# %% [markdown]
# # Conclusion <a name="conclusion"></a>

# %% [markdown]
# Purpose of this project was to identify City of Markham would be a prime location to start any startup high tech companies as   it location consider its Development, Culture, and Multicultural Population. In order to retain the Talents within Canada   particularly Markham as the area of Suggestion and best location. Unless as mention in the Intro the involvement of Government action in establishing the Firms.  However, the Federal Government comes up with various program to retain the Talents within Canada.
